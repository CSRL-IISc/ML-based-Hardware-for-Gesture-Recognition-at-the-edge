# %%
import os
import json
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import random

SEED = 42

random.seed(SEED)
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from sklearn.decomposition import PCA

# %%
import os

os.makedirs("Models", exist_ok=True)

print("Models folder is ready.")
# Out:
# Models folder is ready.

# %%
############################################################
# CONFIG
############################################################

TRAIN_DIR = "/kaggle/input/datasets/vikas635233/dataset-for-train-test/EMG-EPN612 Dataset/trainingJSON"
TEST_DIR = "/kaggle/input/datasets/vikas635233/dataset-for-train-test/EMG-EPN612 Dataset/testingJSON"

TARGET_LEN = 1019
PCA_COMPONENTS = 6

BATCH_SIZE = 32
EPOCHS = 200
LR = 1e-3

############################################################
# LABEL MAP
############################################################

LABEL_MAP = {
    "noGesture": 0,
    "fist": 1,
    "waveIn": 2,
    "waveOut": 3,
    "open": 4,
    "pinch": 5
}

############################################################
# PAD / CROP
############################################################

def pad_or_crop(signal, target_len=TARGET_LEN):

    current_len = signal.shape[1]

    if current_len > target_len:

        signal = signal[:, :target_len]

    elif current_len < target_len:

        pad = target_len - current_len

        signal = np.pad(
            signal,
            ((0, 0), (0, pad)),
            mode='constant'
        )

    return signal

############################################################
# LOAD DATA
############################################################

def load_dataset(folder, allowed_users=None):



    X = []
    y = []

    for root, dirs, files in os.walk(folder):

 

        user_name = os.path.basename(root)

        if allowed_users is not None:
            if user_name not in allowed_users:
               
                continue

        for file in files:

            if not file.endswith(".json"):
                continue

            path = os.path.join(root, file)

        

            with open(path, "r") as f:
                data = json.load(f)

         

            if "trainingSamples" not in data:
               
                continue

            samples = data["trainingSamples"]

           
            for key in samples:

                sample = samples[key]

                gesture = sample["gestureName"]

                if gesture not in LABEL_MAP:
                    
                    continue

                emg = sample["emg"]

                signal = np.array([
                    emg["ch1"],
                    emg["ch2"],
                    emg["ch3"],
                    emg["ch4"],
                    emg["ch5"],
                    emg["ch6"],
                    emg["ch7"],
                    emg["ch8"]
                ], dtype=np.float32)

                signal = pad_or_crop(signal)

                X.append(signal)
                y.append(LABEL_MAP[gesture])


    return np.array(X, dtype=np.float32), np.array(y)

############################################################
# PCA
############################################################

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

def apply_pca(X_train, X_test):

    scaler = StandardScaler()

    pca = PCA(
        n_components=PCA_COMPONENTS
    )

    temp = X_train.transpose(0,2,1)
    temp = temp.reshape(-1,8)

    temp = scaler.fit_transform(temp)

    pca.fit(temp)

    train_out = []

    for sample in X_train:

        sample = sample.T
        sample = scaler.transform(sample)
        sample = pca.transform(sample)
        sample = sample.T

        train_out.append(sample)

    test_out = []

    for sample in X_test:

        sample = sample.T
        sample = scaler.transform(sample)
        sample = pca.transform(sample)
        sample = sample.T

        test_out.append(sample)

    return (
        np.array(train_out, dtype=np.float32),
        np.array(test_out, dtype=np.float32)
    )

# %%
############################################################
# DATASET
############################################################

class EMGDataset(Dataset):

    def __init__(self, X, y):

        self.X = torch.tensor(
            X,
            dtype=torch.float32
        )

        self.y = torch.tensor(
            y,
            dtype=torch.long
        )

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
############################################################
# TERNARY HELPER FUNCTIONS
############################################################

import torch
import torch.nn as nn
import torch.nn.functional as F


class TernarySTE(torch.autograd.Function):

    @staticmethod
    def forward(ctx, weight):

        delta = 0.7 * weight.abs().mean()

        alpha = weight[weight.abs() > delta].abs().mean()

        if torch.isnan(alpha):
            alpha = torch.tensor(
                1.0,
                device=weight.device
            )

        output = torch.zeros_like(weight)

        output[weight > delta] = alpha

        output[weight < -delta] = -alpha

        return output

    @staticmethod
    def backward(ctx, grad_output):

        return grad_output


class TernaryConv1d(nn.Conv1d):

    def forward(self, x):

        ternary_weight = TernarySTE.apply(self.weight)

        return F.conv1d(
            x,
            ternary_weight,
            self.bias,
            self.stride,
            self.padding,
            self.dilation,
            self.groups
        )


class TernaryLinear(nn.Linear):

    def forward(self, x):

        ternary_weight = TernarySTE.apply(self.weight)

        return F.linear(
            x,
            ternary_weight,
            self.bias
        )

# %%
############################################################
# CNN MODEL
############################################################

class Ternary_PCA_CNN(nn.Module):

    def __init__(self):

        super().__init__()

        ############################################################
        # Conv1
        ############################################################

        self.conv1 = TernaryConv1d(
            in_channels=6,
            out_channels=32,
            kernel_size=2
        )

        self.pool = nn.MaxPool1d(2)

        ############################################################
        # Conv2
        ############################################################

        self.conv2 = TernaryConv1d(
            in_channels=32,
            out_channels=32,
            kernel_size=2
        )

        ############################################################
        # GAP
        ############################################################

        self.gap = nn.AdaptiveAvgPool1d(1)

        ############################################################
        # FC
        ############################################################

        self.fc1 = TernaryLinear(
            32,
            64
        )

        self.fc2 = TernaryLinear(
            64,
            6
        )

    def forward(self, x):

        x = F.relu(self.conv1(x))

        x = self.pool(x)

        x = F.relu(self.conv2(x))

        x = self.gap(x)

        x = x.squeeze(-1)

        x = F.relu(self.fc1(x))

        x = self.fc2(x)

        return x

# %%
model = Ternary_PCA_CNN()

print(model)

print("Parameters:",
      sum(p.numel() for p in model.parameters()))
# Out:
# Ternary_PCA_CNN(
#   (conv1): TernaryConv1d(6, 32, kernel_size=(2,), stride=(1,))
#   (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): TernaryConv1d(32, 32, kernel_size=(2,), stride=(1,))
#   (gap): AdaptiveAvgPool1d(output_size=1)
#   (fc1): TernaryLinear(in_features=32, out_features=64, bias=True)
#   (fc2): TernaryLinear(in_features=64, out_features=6, bias=True)
# )
# Parameters: 4998

# %%
############################################################
# LOAD DATA
############################################################
TEST_USERS = [
    "user1","user2","user3","user4","user5",
    "user6","user7","user8","user9","user10",
    "user11","user12","user13","user14","user15",
    "user16","user17","user18","user19","user20",
    "user21"
]
print("Loading data...")

print("TRAIN_DIR =", TRAIN_DIR)
print("TEST_DIR  =", TEST_DIR)

X_train, y_train = load_dataset(TRAIN_DIR)

X_test, y_test = load_dataset(
    TEST_DIR,
    TEST_USERS
)

print("Train shape:", X_train.shape)
print("Test shape :", X_test.shape)

print("X_train:", X_train.shape)
print("y_train:", y_train.shape)

print("X_test :", X_test.shape)
print("y_test :", y_test.shape)

print("Train distribution:")
print(np.unique(y_train, return_counts=True))

print("Test distribution:")
print(np.unique(y_test, return_counts=True))

############################################################
# PCA
############################################################

print("Applying PCA...")

X_train, X_test = apply_pca(
    X_train,
    X_test
)

np.save("X_train_pca.npy", X_train)
np.save("y_train.npy", y_train)

np.save("X_test_pca.npy", X_test)
np.save("y_test.npy", y_test)

print("After PCA")

print("Train :", X_train.shape)
print("Test  :", X_test.shape)

############################################################
# DATALOADER
############################################################

train_dataset = EMGDataset(
    X_train,
    y_train
)

test_dataset = EMGDataset(
    X_test,
    y_test
)

train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False
)
# Out:
# Loading data...
# TRAIN_DIR = /kaggle/input/datasets/vikas635233/dataset-for-train-test/EMG-EPN612 Dataset/trainingJSON
# TEST_DIR  = /kaggle/input/datasets/vikas635233/dataset-for-train-test/EMG-EPN612 Dataset/testingJSON
# Train shape: (45900, 8, 1019)
# Test shape : (3150, 8, 1019)
# X_train: (45900, 8, 1019)
# y_train: (45900,)
# X_test : (3150, 8, 1019)
# y_test : (3150,)
# Train distribution:
# (array([0, 1, 2, 3, 4, 5]), array([7650, 7650, 7650, 7650, 7650, 7650]))
# Test distribution:
# (array([0, 1, 2, 3, 4, 5]), array([525, 525, 525, 525, 525, 525]))
# Applying PCA...
# After PCA
# Train : (45900, 6, 1019)
# Test  : (3150, 6, 1019)

# %%
############################################################
# DEVICE
############################################################

device = torch.device(
    "cuda" if torch.cuda.is_available()
    else "cpu"
)

print("Device:", device)

############################################################
# MODEL
############################################################

model = Ternary_PCA_CNN().to(device)

total_params = sum(p.numel() for p in model.parameters())
print("Total Parameters:", total_params)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=LR
)

############################################################
# TRAIN
############################################################

best_acc = 0

for epoch in range(EPOCHS):

    ########################################################
    # TRAIN
    ########################################################

    model.train()

    train_loss = 0
    train_correct = 0
    train_total = 0

    for x, y in train_loader:

        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad()

        outputs = model(x)

        loss = criterion(
            outputs,
            y
        )

        loss.backward()

        optimizer.step()

        train_loss += loss.item()

        preds = outputs.argmax(1)

        train_total += y.size(0)

        train_correct += (
            preds == y
        ).sum().item()

    train_acc = (
        100.0 *
        train_correct /
        train_total
    )

    ########################################################
    # TEST
    ########################################################

    model.eval()

    test_correct = 0
    test_total = 0

    with torch.no_grad():

        for x, y in test_loader:

            x = x.to(device)
            y = y.to(device)

            outputs = model(x)

            preds = outputs.argmax(1)

            test_total += y.size(0)

            test_correct += (
                preds == y
            ).sum().item()

    test_acc = (
        100.0 *
        test_correct /
        test_total
    )

    ########################################################
    # PRINT RESULTS
    ########################################################

    print(
        f"Epoch {epoch+1:03d} | "
        f"Loss {train_loss:.4f} | "
        f"Train Acc {train_acc:.2f}% | "
        f"Test Acc {test_acc:.2f}%"
    )

    ########################################################
    # SAVE BEST MODEL
    ########################################################

    if test_acc > best_acc:

        best_acc = test_acc

        torch.save(
            model.state_dict(),
            "Models/best_model_ternary_1dcnn.pth"
        )

        print(
            f"Saved model : {best_acc:.2f}%"
        )

print("\nTraining Complete")
print("Best Test Accuracy =", best_acc)
# Out:
# Device: cuda
# Total Parameters: 4998
# Epoch 001 | Loss 1527.8779 | Train Acc 58.38% | Test Acc 73.21%
# Saved model : 73.21%
# Epoch 002 | Loss 960.3440 | Train Acc 76.07% | Test Acc 82.83%
# Saved model : 82.83%
# Epoch 003 | Loss 776.4940 | Train Acc 80.67% | Test Acc 85.49%
# Saved model : 85.49%
# Epoch 004 | Loss 699.4896 | Train Acc 82.56% | Test Acc 86.76%
# Saved model : 86.76%
# Epoch 005 | Loss 653.8460 | Train Acc 83.44% | Test Acc 87.78%
# Saved model : 87.78%
# Epoch 006 | Loss 632.2016 | Train Acc 84.11% | Test Acc 88.67%
# Saved model : 88.67%
# Epoch 007 | Loss 622.7512 | Train Acc 84.40% | Test Acc 87.52%
# Epoch 008 | Loss 613.1923 | Train Acc 84.69% | Test Acc 88.13%
# Epoch 009 | Loss 603.8880 | Train Acc 84.91% | Test Acc 89.33%
# Saved model : 89.33%
# Epoch 010 | Loss 601.0371 | Train Acc 84.98% | Test Acc 89.52%
# Saved model : 89.52%
# Epoch 011 | Loss 597.9825 | Train Acc 85.35% | Test Acc 89.65%
# Saved model : 89.65%
# Epoch 012 | Loss 612.4480 | Train Acc 84.96% | Test Acc 87.37%
# Epoch 013 | Loss 605.5983 | Train Acc 85.13% | Test Acc 89.11%
# Epoch 014 | Loss 602.9609 | Train Acc 85.12% | Test Acc 87.27%
# Epoch 015 | Loss 609.3248 | Train Acc 85.01% | Test Acc 89.21%
# Epoch 016 | Loss 618.2672 | Train Acc 84.96% | Test Acc 88.67%
# Epoch 017 | Loss 636.0762 | Train Acc 84.63% | Test Acc 89.49%
# Epoch 018 | Loss 645.5792 | Train Acc 84.28% | Test Acc 86.03%
# Epoch 019 | Loss 620.6473 | Train Acc 85.05% | Test Acc 89.05%
# Epoch 020 | Loss 629.4304 | Train Acc 84.96% | Test Acc 86.51%
# Epoch 021 | Loss 637.4549 | Train Acc 84.52% | Test Acc 85.68%
# Epoch 022 | Loss 648.5331 | Train Acc 84.43% | Test Acc 87.14%
# Epoch 023 | Loss 647.5540 | Train Acc 84.29% | Test Acc 83.43%
# Epoch 024 | Loss 637.8589 | Train Acc 84.41% | Test Acc 89.43%
# Epoch 025 | Loss 663.2575 | Train Acc 83.81% | Test Acc 87.49%
# Epoch 026 | Loss 672.2758 | Train Acc 83.71% | Test Acc 87.71%
# Epoch 027 | Loss 661.9694 | Train Acc 83.97% | Test Acc 87.11%
# Epoch 028 | Loss 672.7316 | Train Acc 83.92% | Test Acc 85.52%
# Epoch 029 | Loss 672.6868 | Train Acc 83.72% | Test Acc 83.97%
# Epoch 030 | Loss 680.2151 | Train Acc 83.55% | Test Acc 87.71%
# Epoch 031 | Loss 697.1455 | Train Acc 83.16% | Test Acc 83.02%
# Epoch 032 | Loss 716.5374 | Train Acc 82.78% | Test Acc 85.24%
# Epoch 033 | Loss 712.2016 | Train Acc 82.68% | Test Acc 85.30%
# Epoch 034 | Loss 737.9816 | Train Acc 82.11% | Test Acc 86.41%
# Epoch 035 | Loss 746.4990 | Train Acc 81.78% | Test Acc 86.29%
# Epoch 036 | Loss 744.9962 | Train Acc 82.16% | Test Acc 78.67%
# Epoch 037 | Loss 735.8556 | Train Acc 82.19% | Test Acc 86.16%
# Epoch 038 | Loss 747.8855 | Train Acc 82.05% | Test Acc 84.32%
# Epoch 039 | Loss 769.0110 | Train Acc 81.48% | Test Acc 81.14%
# Epoch 040 | Loss 771.4193 | Train Acc 81.55% | Test Acc 86.03%
# Epoch 041 | Loss 768.2601 | Train Acc 81.69% | Test Acc 83.21%
# Epoch 042 | Loss 791.1070 | Train Acc 81.10% | Test Acc 83.40%
# Epoch 043 | Loss 798.5242 | Train Acc 81.03% | Test Acc 83.24%
# Epoch 044 | Loss 819.6584 | Train Acc 80.39% | Test Acc 83.62%
# Epoch 045 | Loss 823.8016 | Train Acc 80.22% | Test Acc 84.57%
# Epoch 046 | Loss 842.3109 | Train Acc 79.94% | Test Acc 83.21%
# Epoch 047 | Loss 840.0372 | Train Acc 79.95% | Test Acc 83.75%
# Epoch 048 | Loss 835.3242 | Train Acc 80.35% | Test Acc 83.49%
# Epoch 049 | Loss 869.3616 | Train Acc 79.38% | Test Acc 84.76%
# Epoch 050 | Loss 873.2777 | Train Acc 79.19% | Test Acc 80.00%
# Epoch 051 | Loss 909.6545 | Train Acc 78.57% | Test Acc 83.68%
# Epoch 052 | Loss 898.0560 | Train Acc 78.80% | Test Acc 85.43%
# Epoch 053 | Loss 920.2015 | Train Acc 78.27% | Test Acc 82.63%
# Epoch 054 | Loss 944.1511 | Train Acc 77.71% | Test Acc 82.60%
# Epoch 055 | Loss 916.7368 | Train Acc 78.63% | Test Acc 81.27%
# Epoch 056 | Loss 917.2305 | Train Acc 78.38% | Test Acc 83.33%
# Epoch 057 | Loss 927.4675 | Train Acc 78.35% | Test Acc 82.35%
# Epoch 058 | Loss 958.7939 | Train Acc 77.43% | Test Acc 84.70%
# Epoch 059 | Loss 956.7286 | Train Acc 77.38% | Test Acc 78.38%
# Epoch 060 | Loss 946.8733 | Train Acc 78.20% | Test Acc 82.95%
# Epoch 061 | Loss 936.1629 | Train Acc 77.96% | Test Acc 83.17%
# Epoch 062 | Loss 930.5619 | Train Acc 78.29% | Test Acc 84.03%
# Epoch 063 | Loss 947.0831 | Train Acc 78.18% | Test Acc 79.52%
# Epoch 064 | Loss 927.8518 | Train Acc 78.35% | Test Acc 81.37%
# Epoch 065 | Loss 956.7783 | Train Acc 77.94% | Test Acc 81.08%
# Epoch 066 | Loss 952.8114 | Train Acc 77.99% | Test Acc 82.13%
# Epoch 067 | Loss 1005.4822 | Train Acc 76.89% | Test Acc 75.43%
# Epoch 068 | Loss 1015.9684 | Train Acc 76.70% | Test Acc 83.49%
# Epoch 069 | Loss 993.3403 | Train Acc 76.97% | Test Acc 80.73%
# Epoch 070 | Loss 1027.2400 | Train Acc 76.38% | Test Acc 78.48%
# Epoch 071 | Loss 1022.4627 | Train Acc 76.51% | Test Acc 81.49%
# Epoch 072 | Loss 1025.7205 | Train Acc 76.06% | Test Acc 72.54%
# Epoch 073 | Loss 1044.1701 | Train Acc 75.79% | Test Acc 74.57%
# Epoch 074 | Loss 1049.3392 | Train Acc 75.46% | Test Acc 80.13%
# Epoch 075 | Loss 1024.7481 | Train Acc 76.27% | Test Acc 77.40%
# Epoch 076 | Loss 1083.0412 | Train Acc 75.28% | Test Acc 79.02%
# Epoch 077 | Loss 1069.9071 | Train Acc 75.35% | Test Acc 80.57%
# Epoch 078 | Loss 1062.2316 | Train Acc 75.41% | Test Acc 79.65%
# Epoch 079 | Loss 1118.4001 | Train Acc 74.32% | Test Acc 66.10%
# Epoch 080 | Loss 1104.4841 | Train Acc 74.66% | Test Acc 78.41%
# Epoch 081 | Loss 1105.5475 | Train Acc 74.77% | Test Acc 77.24%
# Epoch 082 | Loss 1129.7062 | Train Acc 74.00% | Test Acc 77.49%
# Epoch 083 | Loss 1129.8005 | Train Acc 73.99% | Test Acc 76.92%
# Epoch 084 | Loss 1128.7873 | Train Acc 74.27% | Test Acc 81.78%
# Epoch 085 | Loss 1199.7093 | Train Acc 72.54% | Test Acc 76.13%
# Epoch 086 | Loss 1203.9028 | Train Acc 72.51% | Test Acc 70.83%
# Epoch 087 | Loss 1212.5789 | Train Acc 72.57% | Test Acc 72.13%
# Epoch 088 | Loss 1183.3051 | Train Acc 73.09% | Test Acc 80.63%
# Epoch 089 | Loss 1150.1719 | Train Acc 73.71% | Test Acc 71.08%
# Epoch 090 | Loss 1190.9877 | Train Acc 72.80% | Test Acc 75.97%
# Epoch 091 | Loss 1188.3634 | Train Acc 73.17% | Test Acc 65.62%
# Epoch 092 | Loss 1238.5752 | Train Acc 71.86% | Test Acc 77.37%
# Epoch 093 | Loss 1213.3000 | Train Acc 72.51% | Test Acc 74.10%
# Epoch 094 | Loss 1283.4060 | Train Acc 70.89% | Test Acc 76.13%
# Epoch 095 | Loss 1204.6876 | Train Acc 72.85% | Test Acc 75.11%
# Epoch 096 | Loss 1229.0437 | Train Acc 71.71% | Test Acc 76.51%
# Epoch 097 | Loss 1216.6483 | Train Acc 72.48% | Test Acc 76.70%
# Epoch 098 | Loss 1219.7104 | Train Acc 71.83% | Test Acc 69.02%
# Epoch 099 | Loss 1217.8348 | Train Acc 71.69% | Test Acc 78.76%
# Epoch 100 | Loss 1199.0206 | Train Acc 71.91% | Test Acc 74.35%
# Epoch 101 | Loss 1276.6663 | Train Acc 69.59% | Test Acc 76.67%
# Epoch 102 | Loss 1188.2815 | Train Acc 72.29% | Test Acc 79.08%
# Epoch 103 | Loss 1257.8366 | Train Acc 70.35% | Test Acc 65.11%
# Epoch 104 | Loss 1219.1732 | Train Acc 70.67% | Test Acc 77.05%
# Epoch 105 | Loss 1225.3842 | Train Acc 70.26% | Test Acc 68.25%
# Epoch 106 | Loss 1190.5471 | Train Acc 70.30% | Test Acc 71.56%
# Epoch 107 | Loss 1169.9809 | Train Acc 71.80% | Test Acc 71.81%
# Epoch 108 | Loss 1296.1760 | Train Acc 68.79% | Test Acc 71.59%
# Epoch 109 | Loss 1263.9023 | Train Acc 69.73% | Test Acc 68.48%
# Epoch 110 | Loss 1346.3301 | Train Acc 67.20% | Test Acc 66.79%
# Epoch 111 | Loss 1350.2608 | Train Acc 67.60% | Test Acc 52.60%
# Epoch 112 | Loss 1353.0232 | Train Acc 68.00% | Test Acc 68.54%
# Epoch 113 | Loss 1366.5511 | Train Acc 67.95% | Test Acc 68.22%
# Epoch 114 | Loss 1358.7476 | Train Acc 67.66% | Test Acc 75.17%
# Epoch 115 | Loss 1346.8692 | Train Acc 68.29% | Test Acc 73.78%
# Epoch 116 | Loss 1323.4043 | Train Acc 68.32% | Test Acc 67.65%
# Epoch 117 | Loss 1340.9611 | Train Acc 68.51% | Test Acc 75.75%
# Epoch 118 | Loss 1420.1230 | Train Acc 66.29% | Test Acc 72.67%
# Epoch 119 | Loss 1411.1995 | Train Acc 64.94% | Test Acc 63.81%
# Epoch 120 | Loss 1392.0012 | Train Acc 65.57% | Test Acc 68.89%
# Epoch 121 | Loss 1390.3342 | Train Acc 67.56% | Test Acc 75.75%
# Epoch 122 | Loss 1428.8168 | Train Acc 66.61% | Test Acc 69.81%
# Epoch 123 | Loss 1472.9887 | Train Acc 65.13% | Test Acc 65.71%
# Epoch 124 | Loss 1480.2302 | Train Acc 65.14% | Test Acc 70.51%
# Epoch 125 | Loss 1432.7361 | Train Acc 64.83% | Test Acc 69.68%
# Epoch 126 | Loss 1440.6099 | Train Acc 64.05% | Test Acc 63.56%
# Epoch 127 | Loss 1483.9899 | Train Acc 64.79% | Test Acc 60.51%
# Epoch 128 | Loss 1484.1768 | Train Acc 64.16% | Test Acc 58.95%
# Epoch 129 | Loss 1514.6974 | Train Acc 64.02% | Test Acc 70.83%
# Epoch 130 | Loss 1486.5945 | Train Acc 64.79% | Test Acc 60.73%
# Epoch 131 | Loss 1474.3458 | Train Acc 65.41% | Test Acc 67.71%
# Epoch 132 | Loss 1486.6297 | Train Acc 63.97% | Test Acc 67.75%
# Epoch 133 | Loss 1487.8916 | Train Acc 64.07% | Test Acc 53.05%
# Epoch 134 | Loss 1557.8784 | Train Acc 61.51% | Test Acc 71.05%
# Epoch 135 | Loss 1514.2204 | Train Acc 62.30% | Test Acc 56.63%
# Epoch 136 | Loss 1518.0956 | Train Acc 62.16% | Test Acc 56.92%
# Epoch 137 | Loss 1513.7286 | Train Acc 61.12% | Test Acc 61.56%
# Epoch 138 | Loss 1527.1312 | Train Acc 62.13% | Test Acc 65.87%
# Epoch 139 | Loss 1525.0670 | Train Acc 63.45% | Test Acc 61.17%
# Epoch 140 | Loss 1538.1023 | Train Acc 62.07% | Test Acc 70.29%
# Epoch 141 | Loss 1553.8068 | Train Acc 60.00% | Test Acc 61.30%
# Epoch 142 | Loss 1550.9177 | Train Acc 59.71% | Test Acc 61.52%
# Epoch 143 | Loss 1564.5572 | Train Acc 61.70% | Test Acc 63.14%
# Epoch 144 | Loss 1595.4148 | Train Acc 59.56% | Test Acc 62.19%
# Epoch 145 | Loss 1597.8628 | Train Acc 60.27% | Test Acc 62.41%
# Epoch 146 | Loss 1552.0297 | Train Acc 61.58% | Test Acc 62.29%
# Epoch 147 | Loss 1625.4591 | Train Acc 59.73% | Test Acc 54.06%
# Epoch 148 | Loss 1638.7116 | Train Acc 57.95% | Test Acc 56.92%
# Epoch 149 | Loss 1632.0829 | Train Acc 57.98% | Test Acc 56.63%
# Epoch 150 | Loss 1654.4979 | Train Acc 58.78% | Test Acc 58.79%
# Epoch 151 | Loss 1634.1750 | Train Acc 56.94% | Test Acc 56.86%
# Epoch 152 | Loss 1586.6788 | Train Acc 57.30% | Test Acc 66.54%
# Epoch 153 | Loss 1578.9158 | Train Acc 58.78% | Test Acc 58.48%
# Epoch 154 | Loss 1582.0022 | Train Acc 57.87% | Test Acc 58.41%
# Epoch 155 | Loss 1605.5797 | Train Acc 58.61% | Test Acc 58.44%
# Epoch 156 | Loss 1567.9856 | Train Acc 61.42% | Test Acc 61.75%
# Epoch 157 | Loss 1601.8496 | Train Acc 60.39% | Test Acc 64.86%
# Epoch 158 | Loss 1631.5354 | Train Acc 59.05% | Test Acc 61.71%
# Epoch 159 | Loss 1607.1992 | Train Acc 58.59% | Test Acc 50.25%
# Epoch 160 | Loss 1595.5871 | Train Acc 58.50% | Test Acc 61.37%
# Epoch 161 | Loss 1623.9372 | Train Acc 58.31% | Test Acc 66.03%
# Epoch 162 | Loss 1591.9656 | Train Acc 59.31% | Test Acc 54.00%
# Epoch 163 | Loss 1573.6871 | Train Acc 59.74% | Test Acc 55.02%
# Epoch 164 | Loss 1565.6079 | Train Acc 58.87% | Test Acc 57.59%
# Epoch 165 | Loss 1548.5113 | Train Acc 58.80% | Test Acc 64.63%
# Epoch 166 | Loss 1518.5289 | Train Acc 59.52% | Test Acc 64.67%
# Epoch 167 | Loss 1525.2960 | Train Acc 59.15% | Test Acc 66.41%
# Epoch 168 | Loss 1647.5879 | Train Acc 58.17% | Test Acc 61.40%
# Epoch 169 | Loss 1653.3496 | Train Acc 55.15% | Test Acc 56.00%
# Epoch 170 | Loss 1665.6465 | Train Acc 56.66% | Test Acc 52.57%
# Epoch 171 | Loss 1651.0494 | Train Acc 56.43% | Test Acc 60.89%
# Epoch 172 | Loss 1625.9609 | Train Acc 55.58% | Test Acc 56.35%
# Epoch 173 | Loss 1644.6242 | Train Acc 54.96% | Test Acc 60.16%
# Epoch 174 | Loss 1669.5024 | Train Acc 56.90% | Test Acc 65.94%
# Epoch 175 | Loss 1648.8771 | Train Acc 56.52% | Test Acc 58.16%
# Epoch 176 | Loss 1682.8335 | Train Acc 54.15% | Test Acc 66.95%
# Epoch 177 | Loss 1660.1841 | Train Acc 55.28% | Test Acc 62.29%
# Epoch 178 | Loss 1666.9396 | Train Acc 54.65% | Test Acc 56.48%
# Epoch 179 | Loss 1646.6695 | Train Acc 53.70% | Test Acc 51.56%
# Epoch 180 | Loss 1644.0519 | Train Acc 54.26% | Test Acc 56.00%
# Epoch 181 | Loss 1653.6024 | Train Acc 56.16% | Test Acc 55.37%
# Epoch 182 | Loss 1652.3079 | Train Acc 54.66% | Test Acc 57.30%
# Epoch 183 | Loss 1693.4621 | Train Acc 53.23% | Test Acc 63.43%
# Epoch 184 | Loss 1663.9233 | Train Acc 54.31% | Test Acc 50.22%
# Epoch 185 | Loss 1658.4996 | Train Acc 54.03% | Test Acc 51.46%
# Epoch 186 | Loss 1659.8642 | Train Acc 53.92% | Test Acc 49.21%
# Epoch 187 | Loss 1668.8412 | Train Acc 53.39% | Test Acc 59.05%
# Epoch 188 | Loss 1625.3196 | Train Acc 54.23% | Test Acc 42.35%
# Epoch 189 | Loss 1656.9126 | Train Acc 53.41% | Test Acc 44.35%
# Epoch 190 | Loss 1682.7267 | Train Acc 52.46% | Test Acc 52.32%
# Epoch 191 | Loss 1617.6024 | Train Acc 54.48% | Test Acc 58.03%
# Epoch 192 | Loss 1662.8044 | Train Acc 53.00% | Test Acc 56.03%
# Epoch 193 | Loss 1586.9779 | Train Acc 54.30% | Test Acc 55.02%
# Epoch 194 | Loss 1614.3830 | Train Acc 53.25% | Test Acc 53.43%
# Epoch 195 | Loss 1617.2064 | Train Acc 52.62% | Test Acc 53.90%
# Epoch 196 | Loss 1618.0227 | Train Acc 53.42% | Test Acc 57.30%
# Epoch 197 | Loss 1545.1904 | Train Acc 55.51% | Test Acc 59.24%
# Epoch 198 | Loss 1598.8635 | Train Acc 54.73% | Test Acc 58.67%
# Epoch 199 | Loss 1636.1632 | Train Acc 54.59% | Test Acc 51.78%
# Epoch 200 | Loss 1594.6037 | Train Acc 53.73% | Test Acc 52.60%
#
# Training Complete
# Best Test Accuracy = 89.65079365079364

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

model.load_state_dict(
    torch.load("Models/best_model_ternary_1dcnn.pth")
)

model.eval()

y_true = []
y_pred = []

with torch.no_grad():

    for x, y in test_loader:

        x = x.to(device)

        outputs = model(x)

        preds = outputs.argmax(1)

        y_true.extend(y.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

print("Confusion Matrix")
print(confusion_matrix(y_true, y_pred))

print("\nClassification Report")
print(classification_report(y_true, y_pred))
# Out:
# Confusion Matrix
# [[523   0   1   0   0   1]
#  [  1 482   9   0  10  23]
#  [  0   0 518   3   0   4]
#  [  2   0  12 474  37   0]
#  [  1  17  13  21 456  17]
#  [ 11  18  10  30  85 371]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       525
#            1       0.93      0.92      0.93       525
#            2       0.92      0.99      0.95       525
#            3       0.90      0.90      0.90       525
#            4       0.78      0.87      0.82       525
#            5       0.89      0.71      0.79       525
#
#     accuracy                           0.90      3150
#    macro avg       0.90      0.90      0.89      3150
# weighted avg       0.90      0.90      0.89      3150

# %%
print("Conv1 :", model.conv1.weight.numel())
print("Conv2 :", model.conv2.weight.numel())

print("FC1 :", model.fc1.weight.numel())
print("FC2 :", model.fc2.weight.numel())

print("\nTotal Parameters:",
      sum(p.numel() for p in model.parameters()))
# Out:
# Conv1 : 384
# Conv2 : 2048
# FC1 : 2048
# FC2 : 384
#
# Total Parameters: 4998

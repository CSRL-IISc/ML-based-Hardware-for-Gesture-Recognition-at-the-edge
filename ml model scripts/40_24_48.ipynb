# %%
import os
import json
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import random

SEED = 42

random.seed(SEED)
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from sklearn.decomposition import PCA

# %%
import os

os.makedirs("Models", exist_ok=True)

print("Models folder is ready.")
# Out:
# Models folder is ready.

# %%
############################################################
# CONFIG
############################################################

TRAIN_DIR = "/kaggle/input/datasets/vikas635233/dataset-for-train-test/EMG-EPN612 Dataset/trainingJSON"
TEST_DIR = "/kaggle/input/datasets/vikas635233/dataset-for-train-test/EMG-EPN612 Dataset/testingJSON"

TARGET_LEN = 1019
PCA_COMPONENTS = 6

BATCH_SIZE = 32
EPOCHS = 200
LR = 1e-3

############################################################
# LABEL MAP
############################################################

LABEL_MAP = {
    "noGesture": 0,
    "fist": 1,
    "waveIn": 2,
    "waveOut": 3,
    "open": 4,
    "pinch": 5
}

############################################################
# PAD / CROP
############################################################

def pad_or_crop(signal, target_len=TARGET_LEN):

    current_len = signal.shape[1]

    if current_len > target_len:

        signal = signal[:, :target_len]

    elif current_len < target_len:

        pad = target_len - current_len

        signal = np.pad(
            signal,
            ((0, 0), (0, pad)),
            mode='constant'
        )

    return signal

############################################################
# LOAD DATA
############################################################

def load_dataset(folder, allowed_users=None):



    X = []
    y = []

    for root, dirs, files in os.walk(folder):

 

        user_name = os.path.basename(root)

        if allowed_users is not None:
            if user_name not in allowed_users:
               
                continue

        for file in files:

            if not file.endswith(".json"):
                continue

            path = os.path.join(root, file)

        

            with open(path, "r") as f:
                data = json.load(f)

         

            if "trainingSamples" not in data:
               
                continue

            samples = data["trainingSamples"]

           
            for key in samples:

                sample = samples[key]

                gesture = sample["gestureName"]

                if gesture not in LABEL_MAP:
                    
                    continue

                emg = sample["emg"]

                signal = np.array([
                    emg["ch1"],
                    emg["ch2"],
                    emg["ch3"],
                    emg["ch4"],
                    emg["ch5"],
                    emg["ch6"],
                    emg["ch7"],
                    emg["ch8"]
                ], dtype=np.float32)

                signal = pad_or_crop(signal)

                X.append(signal)
                y.append(LABEL_MAP[gesture])


    return np.array(X, dtype=np.float32), np.array(y)

############################################################
# PCA
############################################################

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

def apply_pca(X_train, X_test):

    scaler = StandardScaler()

    pca = PCA(
        n_components=PCA_COMPONENTS
    )

    temp = X_train.transpose(0,2,1)
    temp = temp.reshape(-1,8)

    temp = scaler.fit_transform(temp)

    pca.fit(temp)

    train_out = []

    for sample in X_train:

        sample = sample.T
        sample = scaler.transform(sample)
        sample = pca.transform(sample)
        sample = sample.T

        train_out.append(sample)

    test_out = []

    for sample in X_test:

        sample = sample.T
        sample = scaler.transform(sample)
        sample = pca.transform(sample)
        sample = sample.T

        test_out.append(sample)

    return (
        np.array(train_out, dtype=np.float32),
        np.array(test_out, dtype=np.float32)
    )

# %%
############################################################
# DATASET
############################################################

class EMGDataset(Dataset):

    def __init__(self, X, y):

        self.X = torch.tensor(
            X,
            dtype=torch.float32
        )

        self.y = torch.tensor(
            y,
            dtype=torch.long
        )

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

############################################################
# CNN MODEL
############################################################

# %%
############################################################
# CNN MODEL
############################################################

class PCA_CNN(nn.Module):

    def __init__(self):

        super().__init__()

        ############################################################
        # Conv1
        ############################################################

        self.conv1 = nn.Conv1d(
            in_channels=6,
            out_channels=40,
            kernel_size=2
        )

        self.pool = nn.MaxPool1d(
            kernel_size=2
        )

        ############################################################
        # Conv2 (64 -> 52 filters)
        ############################################################

        self.conv2 = nn.Conv1d(
            in_channels=40,
            out_channels=24,
            kernel_size=2
        )

        ############################################################
        # GAP
        ############################################################

        self.gap = nn.AdaptiveAvgPool1d(1)

        ############################################################
        # FC
        ############################################################

        self.fc1 = nn.Linear(
            24,
            48
        )

        self.fc2 = nn.Linear(
            48,
            6
        )

    def forward(self, x):

        x = self.conv1(x)
        x = F.relu(x)

        x = self.pool(x)

        x = self.conv2(x)
        x = F.relu(x)

        x = self.gap(x)

        x = x.squeeze(-1)

        x = self.fc1(x)
        x = F.relu(x)

        x = self.fc2(x)

        return x

# %%
model = PCA_CNN()
print(model)

print("Parameters:",
      sum(p.numel() for p in model.parameters()))
# Out:
# PCA_CNN(
#   (conv1): Conv1d(6, 40, kernel_size=(2,), stride=(1,))
#   (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(40, 24, kernel_size=(2,), stride=(1,))
#   (gap): AdaptiveAvgPool1d(output_size=1)
#   (fc1): Linear(in_features=24, out_features=48, bias=True)
#   (fc2): Linear(in_features=48, out_features=6, bias=True)
# )
# Parameters: 3958

# %%
############################################################
# LOAD DATA
############################################################
TEST_USERS = [
    "user1","user2","user3","user4","user5",
    "user6","user7","user8","user9","user10",
    "user11","user12","user13","user14","user15",
    "user16","user17","user18","user19","user20",
    "user21"
]
print("Loading data...")

print("TRAIN_DIR =", TRAIN_DIR)
print("TEST_DIR  =", TEST_DIR)

X_train, y_train = load_dataset(TRAIN_DIR)

X_test, y_test = load_dataset(
    TEST_DIR,
    TEST_USERS
)

print("Train shape:", X_train.shape)
print("Test shape :", X_test.shape)

print("X_train:", X_train.shape)
print("y_train:", y_train.shape)

print("X_test :", X_test.shape)
print("y_test :", y_test.shape)

print("Train distribution:")
print(np.unique(y_train, return_counts=True))

print("Test distribution:")
print(np.unique(y_test, return_counts=True))

############################################################
# PCA
############################################################

print("Applying PCA...")

X_train, X_test = apply_pca(
    X_train,
    X_test
)

np.save("X_train_pca.npy", X_train)
np.save("y_train.npy", y_train)

np.save("X_test_pca.npy", X_test)
np.save("y_test.npy", y_test)

print("After PCA")

print("Train :", X_train.shape)
print("Test  :", X_test.shape)

############################################################
# DATALOADER
############################################################

train_dataset = EMGDataset(
    X_train,
    y_train
)

test_dataset = EMGDataset(
    X_test,
    y_test
)

train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False
)
# Out:
# Loading data...
# TRAIN_DIR = /kaggle/input/datasets/vikas635233/dataset-for-train-test/EMG-EPN612 Dataset/trainingJSON
# TEST_DIR  = /kaggle/input/datasets/vikas635233/dataset-for-train-test/EMG-EPN612 Dataset/testingJSON
# Train shape: (45900, 8, 1019)
# Test shape : (3150, 8, 1019)
# X_train: (45900, 8, 1019)
# y_train: (45900,)
# X_test : (3150, 8, 1019)
# y_test : (3150,)
# Train distribution:
# (array([0, 1, 2, 3, 4, 5]), array([7650, 7650, 7650, 7650, 7650, 7650]))
# Test distribution:
# (array([0, 1, 2, 3, 4, 5]), array([525, 525, 525, 525, 525, 525]))
# Applying PCA...
# After PCA
# Train : (45900, 6, 1019)
# Test  : (3150, 6, 1019)

# %%
############################################################
# DEVICE
############################################################

device = torch.device(
    "cuda" if torch.cuda.is_available()
    else "cpu"
)

print("Device:", device)

############################################################
# MODEL
############################################################

model = PCA_CNN().to(device)

total_params = sum(p.numel() for p in model.parameters())
print("Total Parameters:", total_params)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=LR
)

############################################################
# TRAIN
############################################################

best_acc = 0

for epoch in range(EPOCHS):

    ########################################################
    # TRAIN
    ########################################################

    model.train()

    train_loss = 0
    train_correct = 0
    train_total = 0

    for x, y in train_loader:

        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad()

        outputs = model(x)

        loss = criterion(
            outputs,
            y
        )

        loss.backward()

        optimizer.step()

        train_loss += loss.item()

        preds = outputs.argmax(1)

        train_total += y.size(0)

        train_correct += (
            preds == y
        ).sum().item()

    train_acc = (
        100.0 *
        train_correct /
        train_total
    )

    ########################################################
    # TEST
    ########################################################

    model.eval()

    test_correct = 0
    test_total = 0

    with torch.no_grad():

        for x, y in test_loader:

            x = x.to(device)
            y = y.to(device)

            outputs = model(x)

            preds = outputs.argmax(1)

            test_total += y.size(0)

            test_correct += (
                preds == y
            ).sum().item()

    test_acc = (
        100.0 *
        test_correct /
        test_total
    )

    ########################################################
    # PRINT RESULTS
    ########################################################

    print(
        f"Epoch {epoch+1:03d} | "
        f"Loss {train_loss:.4f} | "
        f"Train Acc {train_acc:.2f}% | "
        f"Test Acc {test_acc:.2f}%"
    )

    ########################################################
    # SAVE BEST MODEL
    ########################################################

    if test_acc > best_acc:

        best_acc = test_acc

        torch.save(
    model.state_dict(),
    "Models/best_model_40_24_48.pth"
)

        print(
            f"Saved model : {best_acc:.2f}%"
        )

print("\nTraining Complete")
print("Best Test Accuracy =", best_acc)
# Out:
# Device: cuda
# Total Parameters: 3958
# Epoch 001 | Loss 1284.4615 | Train Acc 66.53% | Test Acc 84.16%
# Saved model : 84.16%
# Epoch 002 | Loss 715.5155 | Train Acc 82.85% | Test Acc 85.43%
# Saved model : 85.43%
# Epoch 003 | Loss 617.3472 | Train Acc 85.07% | Test Acc 88.32%
# Saved model : 88.32%
# Epoch 004 | Loss 555.6946 | Train Acc 86.27% | Test Acc 89.37%
# Saved model : 89.37%
# Epoch 005 | Loss 518.0511 | Train Acc 87.09% | Test Acc 89.37%
# Epoch 006 | Loss 489.9191 | Train Acc 87.58% | Test Acc 90.51%
# Saved model : 90.51%
# Epoch 007 | Loss 467.4052 | Train Acc 88.15% | Test Acc 90.86%
# Saved model : 90.86%
# Epoch 008 | Loss 446.5094 | Train Acc 88.63% | Test Acc 90.73%
# Epoch 009 | Loss 430.0187 | Train Acc 88.93% | Test Acc 90.98%
# Saved model : 90.98%
# Epoch 010 | Loss 414.8680 | Train Acc 89.41% | Test Acc 90.35%
# Epoch 011 | Loss 404.4222 | Train Acc 89.66% | Test Acc 91.49%
# Saved model : 91.49%
# Epoch 012 | Loss 393.2926 | Train Acc 89.92% | Test Acc 91.46%
# Epoch 013 | Loss 381.6628 | Train Acc 90.25% | Test Acc 89.56%
# Epoch 014 | Loss 375.6462 | Train Acc 90.36% | Test Acc 91.90%
# Saved model : 91.90%
# Epoch 015 | Loss 364.8926 | Train Acc 90.66% | Test Acc 92.32%
# Saved model : 92.32%
# Epoch 016 | Loss 359.3643 | Train Acc 90.75% | Test Acc 92.06%
# Epoch 017 | Loss 349.1886 | Train Acc 91.11% | Test Acc 92.10%
# Epoch 018 | Loss 343.9661 | Train Acc 91.19% | Test Acc 91.75%
# Epoch 019 | Loss 337.0423 | Train Acc 91.34% | Test Acc 91.87%
# Epoch 020 | Loss 329.5066 | Train Acc 91.65% | Test Acc 92.06%
# Epoch 021 | Loss 323.5718 | Train Acc 91.81% | Test Acc 92.48%
# Saved model : 92.48%
# Epoch 022 | Loss 319.5785 | Train Acc 91.98% | Test Acc 92.29%
# Epoch 023 | Loss 315.0638 | Train Acc 92.12% | Test Acc 92.03%
# Epoch 024 | Loss 309.8526 | Train Acc 92.15% | Test Acc 92.73%
# Saved model : 92.73%
# Epoch 025 | Loss 305.8774 | Train Acc 92.31% | Test Acc 91.37%
# Epoch 026 | Loss 300.5717 | Train Acc 92.43% | Test Acc 92.79%
# Saved model : 92.79%
# Epoch 027 | Loss 294.6773 | Train Acc 92.61% | Test Acc 92.00%
# Epoch 028 | Loss 291.6457 | Train Acc 92.64% | Test Acc 92.41%
# Epoch 029 | Loss 286.4420 | Train Acc 92.90% | Test Acc 92.00%
# Epoch 030 | Loss 284.8831 | Train Acc 92.83% | Test Acc 92.41%
# Epoch 031 | Loss 278.7441 | Train Acc 93.01% | Test Acc 92.48%
# Epoch 032 | Loss 276.8636 | Train Acc 93.10% | Test Acc 92.32%
# Epoch 033 | Loss 272.0531 | Train Acc 93.18% | Test Acc 92.22%
# Epoch 034 | Loss 268.7479 | Train Acc 93.20% | Test Acc 92.70%
# Epoch 035 | Loss 266.7054 | Train Acc 93.39% | Test Acc 92.44%
# Epoch 036 | Loss 264.4247 | Train Acc 93.33% | Test Acc 93.08%
# Saved model : 93.08%
# Epoch 037 | Loss 261.2004 | Train Acc 93.47% | Test Acc 92.86%
# Epoch 038 | Loss 258.6898 | Train Acc 93.55% | Test Acc 92.98%
# Epoch 039 | Loss 255.3481 | Train Acc 93.52% | Test Acc 92.83%
# Epoch 040 | Loss 251.7785 | Train Acc 93.71% | Test Acc 92.22%
# Epoch 041 | Loss 251.4138 | Train Acc 93.64% | Test Acc 91.78%
# Epoch 042 | Loss 247.5382 | Train Acc 93.69% | Test Acc 93.17%
# Saved model : 93.17%
# Epoch 043 | Loss 247.2473 | Train Acc 93.89% | Test Acc 93.05%
# Epoch 044 | Loss 243.4541 | Train Acc 93.90% | Test Acc 93.30%
# Saved model : 93.30%
# Epoch 045 | Loss 241.9728 | Train Acc 93.95% | Test Acc 93.08%
# Epoch 046 | Loss 240.1015 | Train Acc 94.00% | Test Acc 93.33%
# Saved model : 93.33%
# Epoch 047 | Loss 235.9434 | Train Acc 94.08% | Test Acc 93.17%
# Epoch 048 | Loss 236.5399 | Train Acc 94.06% | Test Acc 91.97%
# Epoch 049 | Loss 232.6689 | Train Acc 94.13% | Test Acc 92.98%
# Epoch 050 | Loss 231.6101 | Train Acc 94.19% | Test Acc 93.08%
# Epoch 051 | Loss 231.5275 | Train Acc 94.13% | Test Acc 93.05%
# Epoch 052 | Loss 226.7066 | Train Acc 94.29% | Test Acc 92.60%
# Epoch 053 | Loss 228.1505 | Train Acc 94.22% | Test Acc 92.41%
# Epoch 054 | Loss 229.2589 | Train Acc 94.32% | Test Acc 92.73%
# Epoch 055 | Loss 223.2575 | Train Acc 94.38% | Test Acc 93.14%
# Epoch 056 | Loss 223.1644 | Train Acc 94.35% | Test Acc 93.21%
# Epoch 057 | Loss 223.4015 | Train Acc 94.39% | Test Acc 92.57%
# Epoch 058 | Loss 219.2265 | Train Acc 94.62% | Test Acc 92.89%
# Epoch 059 | Loss 219.4304 | Train Acc 94.50% | Test Acc 92.67%
# Epoch 060 | Loss 218.4829 | Train Acc 94.60% | Test Acc 93.08%
# Epoch 061 | Loss 215.2427 | Train Acc 94.61% | Test Acc 92.48%
# Epoch 062 | Loss 215.1940 | Train Acc 94.64% | Test Acc 93.14%
# Epoch 063 | Loss 215.5121 | Train Acc 94.63% | Test Acc 92.92%
# Epoch 064 | Loss 213.1919 | Train Acc 94.70% | Test Acc 93.24%
# Epoch 065 | Loss 209.3385 | Train Acc 94.60% | Test Acc 93.08%
# Epoch 066 | Loss 209.4981 | Train Acc 94.74% | Test Acc 93.17%
# Epoch 067 | Loss 210.1217 | Train Acc 94.71% | Test Acc 92.79%
# Epoch 068 | Loss 207.9423 | Train Acc 94.75% | Test Acc 92.86%
# Epoch 069 | Loss 203.5871 | Train Acc 94.86% | Test Acc 91.59%
# Epoch 070 | Loss 205.5365 | Train Acc 94.84% | Test Acc 92.73%
# Epoch 071 | Loss 205.5726 | Train Acc 94.75% | Test Acc 92.73%
# Epoch 072 | Loss 203.1072 | Train Acc 94.91% | Test Acc 93.14%
# Epoch 073 | Loss 201.9325 | Train Acc 94.95% | Test Acc 92.41%
# Epoch 074 | Loss 198.6457 | Train Acc 94.98% | Test Acc 92.13%
# Epoch 075 | Loss 200.1692 | Train Acc 95.02% | Test Acc 92.76%
# Epoch 076 | Loss 200.5749 | Train Acc 94.98% | Test Acc 92.06%
# Epoch 077 | Loss 195.1574 | Train Acc 95.12% | Test Acc 92.95%
# Epoch 078 | Loss 197.4366 | Train Acc 95.01% | Test Acc 93.02%
# Epoch 079 | Loss 193.6245 | Train Acc 95.11% | Test Acc 92.76%
# Epoch 080 | Loss 193.9774 | Train Acc 95.09% | Test Acc 92.76%
# Epoch 081 | Loss 193.6883 | Train Acc 95.22% | Test Acc 92.95%
# Epoch 082 | Loss 192.5486 | Train Acc 95.12% | Test Acc 91.81%
# Epoch 083 | Loss 189.1000 | Train Acc 95.31% | Test Acc 92.95%
# Epoch 084 | Loss 189.5743 | Train Acc 95.25% | Test Acc 92.63%
# Epoch 085 | Loss 190.7100 | Train Acc 95.17% | Test Acc 92.73%
# Epoch 086 | Loss 186.6190 | Train Acc 95.35% | Test Acc 92.73%
# Epoch 087 | Loss 186.3971 | Train Acc 95.30% | Test Acc 92.44%
# Epoch 088 | Loss 184.9577 | Train Acc 95.39% | Test Acc 92.48%
# Epoch 089 | Loss 185.4426 | Train Acc 95.33% | Test Acc 92.92%
# Epoch 090 | Loss 184.7976 | Train Acc 95.40% | Test Acc 92.29%
# Epoch 091 | Loss 182.4214 | Train Acc 95.46% | Test Acc 93.49%
# Saved model : 93.49%
# Epoch 092 | Loss 182.0937 | Train Acc 95.41% | Test Acc 91.49%
# Epoch 093 | Loss 179.5841 | Train Acc 95.47% | Test Acc 92.16%
# Epoch 094 | Loss 182.0483 | Train Acc 95.43% | Test Acc 92.51%
# Epoch 095 | Loss 178.9835 | Train Acc 95.55% | Test Acc 92.67%
# Epoch 096 | Loss 178.0275 | Train Acc 95.63% | Test Acc 92.79%
# Epoch 097 | Loss 177.6282 | Train Acc 95.63% | Test Acc 92.83%
# Epoch 098 | Loss 175.3813 | Train Acc 95.65% | Test Acc 92.16%
# Epoch 099 | Loss 175.6873 | Train Acc 95.59% | Test Acc 92.54%
# Epoch 100 | Loss 176.7044 | Train Acc 95.64% | Test Acc 92.54%
# Epoch 101 | Loss 173.3704 | Train Acc 95.59% | Test Acc 92.76%
# Epoch 102 | Loss 171.9430 | Train Acc 95.68% | Test Acc 92.60%
# Epoch 103 | Loss 174.3392 | Train Acc 95.69% | Test Acc 92.25%
# Epoch 104 | Loss 171.0110 | Train Acc 95.73% | Test Acc 92.22%
# Epoch 105 | Loss 171.8770 | Train Acc 95.69% | Test Acc 92.29%
# Epoch 106 | Loss 171.4053 | Train Acc 95.69% | Test Acc 92.25%
# Epoch 107 | Loss 168.3367 | Train Acc 95.82% | Test Acc 92.95%
# Epoch 108 | Loss 169.2949 | Train Acc 95.87% | Test Acc 92.92%
# Epoch 109 | Loss 168.9070 | Train Acc 95.76% | Test Acc 92.95%
# Epoch 110 | Loss 169.2628 | Train Acc 95.79% | Test Acc 92.89%
# Epoch 111 | Loss 164.5572 | Train Acc 95.90% | Test Acc 92.92%
# Epoch 112 | Loss 165.9912 | Train Acc 95.81% | Test Acc 92.57%
# Epoch 113 | Loss 168.0781 | Train Acc 95.83% | Test Acc 92.73%
# Epoch 114 | Loss 162.6455 | Train Acc 95.88% | Test Acc 92.63%
# Epoch 115 | Loss 166.1136 | Train Acc 95.92% | Test Acc 93.02%
# Epoch 116 | Loss 164.0106 | Train Acc 95.85% | Test Acc 93.27%
# Epoch 117 | Loss 163.2417 | Train Acc 95.92% | Test Acc 92.79%
# Epoch 118 | Loss 161.9801 | Train Acc 96.01% | Test Acc 93.27%
# Epoch 119 | Loss 162.4716 | Train Acc 95.95% | Test Acc 92.79%
# Epoch 120 | Loss 158.6568 | Train Acc 96.08% | Test Acc 92.44%
# Epoch 121 | Loss 160.0598 | Train Acc 95.96% | Test Acc 92.76%
# Epoch 122 | Loss 160.5179 | Train Acc 96.09% | Test Acc 92.76%
# Epoch 123 | Loss 157.3946 | Train Acc 96.08% | Test Acc 92.44%
# Epoch 124 | Loss 160.3181 | Train Acc 96.07% | Test Acc 92.19%
# Epoch 125 | Loss 159.4355 | Train Acc 96.05% | Test Acc 92.79%
# Epoch 126 | Loss 159.3478 | Train Acc 96.09% | Test Acc 92.60%
# Epoch 127 | Loss 158.2238 | Train Acc 96.09% | Test Acc 92.00%
# Epoch 128 | Loss 154.5921 | Train Acc 96.19% | Test Acc 92.86%
# Epoch 129 | Loss 158.1803 | Train Acc 96.06% | Test Acc 92.51%
# Epoch 130 | Loss 155.0991 | Train Acc 96.14% | Test Acc 92.22%
# Epoch 131 | Loss 152.2746 | Train Acc 96.27% | Test Acc 92.73%
# Epoch 132 | Loss 155.7565 | Train Acc 96.19% | Test Acc 92.51%
# Epoch 133 | Loss 155.1048 | Train Acc 96.20% | Test Acc 93.17%
# Epoch 134 | Loss 152.9171 | Train Acc 96.15% | Test Acc 92.70%
# Epoch 135 | Loss 152.8586 | Train Acc 96.16% | Test Acc 93.11%
# Epoch 136 | Loss 153.8306 | Train Acc 96.16% | Test Acc 92.83%
# Epoch 137 | Loss 152.5914 | Train Acc 96.16% | Test Acc 92.70%
# Epoch 138 | Loss 150.4115 | Train Acc 96.25% | Test Acc 92.67%
# Epoch 139 | Loss 151.4173 | Train Acc 96.24% | Test Acc 92.57%
# Epoch 140 | Loss 152.2445 | Train Acc 96.23% | Test Acc 92.89%
# Epoch 141 | Loss 146.3610 | Train Acc 96.31% | Test Acc 92.76%
# Epoch 142 | Loss 148.6162 | Train Acc 96.25% | Test Acc 92.63%
# Epoch 143 | Loss 148.8731 | Train Acc 96.31% | Test Acc 91.94%
# Epoch 144 | Loss 147.6772 | Train Acc 96.38% | Test Acc 92.89%
# Epoch 145 | Loss 147.6438 | Train Acc 96.25% | Test Acc 92.92%
# Epoch 146 | Loss 145.9736 | Train Acc 96.37% | Test Acc 92.35%
# Epoch 147 | Loss 146.8679 | Train Acc 96.45% | Test Acc 92.70%
# Epoch 148 | Loss 146.4554 | Train Acc 96.35% | Test Acc 92.92%
# Epoch 149 | Loss 145.6068 | Train Acc 96.42% | Test Acc 92.48%
# Epoch 150 | Loss 146.0810 | Train Acc 96.36% | Test Acc 92.60%
# Epoch 151 | Loss 141.9461 | Train Acc 96.49% | Test Acc 92.35%
# Epoch 152 | Loss 144.3800 | Train Acc 96.36% | Test Acc 93.33%
# Epoch 153 | Loss 141.8758 | Train Acc 96.49% | Test Acc 92.57%
# Epoch 154 | Loss 143.0324 | Train Acc 96.43% | Test Acc 92.29%
# Epoch 155 | Loss 144.7313 | Train Acc 96.42% | Test Acc 92.41%
# Epoch 156 | Loss 145.3508 | Train Acc 96.37% | Test Acc 92.03%
# Epoch 157 | Loss 140.2179 | Train Acc 96.51% | Test Acc 92.92%
# Epoch 158 | Loss 143.4005 | Train Acc 96.44% | Test Acc 92.73%
# Epoch 159 | Loss 139.1587 | Train Acc 96.54% | Test Acc 92.35%
# Epoch 160 | Loss 140.5398 | Train Acc 96.54% | Test Acc 91.81%
# Epoch 161 | Loss 142.7539 | Train Acc 96.49% | Test Acc 92.25%
# Epoch 162 | Loss 142.8813 | Train Acc 96.49% | Test Acc 93.02%
# Epoch 163 | Loss 141.1501 | Train Acc 96.49% | Test Acc 92.79%
# Epoch 164 | Loss 140.5200 | Train Acc 96.55% | Test Acc 92.98%
# Epoch 165 | Loss 138.9957 | Train Acc 96.54% | Test Acc 92.41%
# Epoch 166 | Loss 138.5079 | Train Acc 96.52% | Test Acc 92.35%
# Epoch 167 | Loss 137.1922 | Train Acc 96.60% | Test Acc 92.48%
# Epoch 168 | Loss 138.7820 | Train Acc 96.67% | Test Acc 92.89%
# Epoch 169 | Loss 137.3179 | Train Acc 96.60% | Test Acc 92.51%
# Epoch 170 | Loss 138.6539 | Train Acc 96.53% | Test Acc 92.89%
# Epoch 171 | Loss 136.8334 | Train Acc 96.63% | Test Acc 92.13%
# Epoch 172 | Loss 134.7485 | Train Acc 96.64% | Test Acc 92.73%
# Epoch 173 | Loss 138.0964 | Train Acc 96.52% | Test Acc 92.70%
# Epoch 174 | Loss 134.0547 | Train Acc 96.66% | Test Acc 92.63%
# Epoch 175 | Loss 134.6356 | Train Acc 96.71% | Test Acc 92.67%
# Epoch 176 | Loss 132.2614 | Train Acc 96.71% | Test Acc 92.86%
# Epoch 177 | Loss 136.8340 | Train Acc 96.61% | Test Acc 92.41%
# Epoch 178 | Loss 133.6428 | Train Acc 96.71% | Test Acc 93.14%
# Epoch 179 | Loss 133.0459 | Train Acc 96.65% | Test Acc 91.87%
# Epoch 180 | Loss 133.1540 | Train Acc 96.76% | Test Acc 93.11%
# Epoch 181 | Loss 132.1595 | Train Acc 96.73% | Test Acc 92.89%
# Epoch 182 | Loss 134.3302 | Train Acc 96.62% | Test Acc 92.00%
# Epoch 183 | Loss 132.7357 | Train Acc 96.72% | Test Acc 92.51%
# Epoch 184 | Loss 129.3313 | Train Acc 96.80% | Test Acc 92.57%
# Epoch 185 | Loss 132.1901 | Train Acc 96.76% | Test Acc 93.02%
# Epoch 186 | Loss 132.3022 | Train Acc 96.71% | Test Acc 92.60%
# Epoch 187 | Loss 135.5728 | Train Acc 96.62% | Test Acc 92.79%
# Epoch 188 | Loss 133.2890 | Train Acc 96.72% | Test Acc 92.03%
# Epoch 189 | Loss 131.7413 | Train Acc 96.70% | Test Acc 92.89%
# Epoch 190 | Loss 129.2434 | Train Acc 96.83% | Test Acc 92.38%
# Epoch 191 | Loss 129.9003 | Train Acc 96.75% | Test Acc 92.54%
# Epoch 192 | Loss 128.1869 | Train Acc 96.87% | Test Acc 92.51%
# Epoch 193 | Loss 127.6630 | Train Acc 96.85% | Test Acc 92.86%
# Epoch 194 | Loss 130.3590 | Train Acc 96.83% | Test Acc 92.57%
# Epoch 195 | Loss 131.1533 | Train Acc 96.68% | Test Acc 93.33%
# Epoch 196 | Loss 130.0445 | Train Acc 96.72% | Test Acc 92.32%
# Epoch 197 | Loss 127.7943 | Train Acc 96.92% | Test Acc 91.90%
# Epoch 198 | Loss 128.1056 | Train Acc 96.85% | Test Acc 92.51%
# Epoch 199 | Loss 129.3084 | Train Acc 96.76% | Test Acc 92.35%
# Epoch 200 | Loss 127.9939 | Train Acc 96.87% | Test Acc 92.19%
#
# Training Complete
# Best Test Accuracy = 93.4920634920635

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

model.load_state_dict(
    torch.load("Models/best_model_40_24_48.pth")
)

model.eval()

y_true = []
y_pred = []

with torch.no_grad():

    for x, y in test_loader:

        x = x.to(device)

        outputs = model(x)

        preds = outputs.argmax(1)

        y_true.extend(y.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

print("Confusion Matrix")
print(confusion_matrix(y_true, y_pred))

print("\nClassification Report")
print(classification_report(y_true, y_pred))
# Out:
# Confusion Matrix
# [[520   1   1   0   0   3]
#  [  0 499   2   0   8  16]
#  [  0   1 518   3   0   3]
#  [  2   0   8 481  33   1]
#  [  0  11   4  17 459  34]
#  [  1  21   2   1  32 468]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       525
#            1       0.94      0.95      0.94       525
#            2       0.97      0.99      0.98       525
#            3       0.96      0.92      0.94       525
#            4       0.86      0.87      0.87       525
#            5       0.89      0.89      0.89       525
#
#     accuracy                           0.93      3150
#    macro avg       0.94      0.93      0.93      3150
# weighted avg       0.94      0.93      0.93      3150

# %%
############################################################
# WEIGHT QUANTIZATION
############################################################
def quantize_weights(weights, bits):

    qmin = -(2 ** (bits - 1))
    qmax = (2 ** (bits - 1)) - 1

    # Linear layer
    if weights.ndim == 2:

        out = torch.empty_like(weights)

        for i in range(weights.size(0)):

            w = weights[i]

            max_val = w.abs().max()

            if max_val == 0:
                out[i] = w
                continue

            scale = max_val / qmax

            q = torch.round(w / scale)
            q = torch.clamp(q, qmin, qmax)

            out[i] = q * scale

        return out

    # Conv1D layer
    elif weights.ndim == 3:

        out = torch.empty_like(weights)

        for i in range(weights.size(0)):

            w = weights[i]

            max_val = w.abs().max()

            if max_val == 0:
                out[i] = w
                continue

            scale = max_val / qmax

            q = torch.round(w / scale)
            q = torch.clamp(q, qmin, qmax)

            out[i] = q * scale

        return out

    # Bias or scalar
    else:

        max_val = weights.abs().max()

        if max_val == 0:
            return weights.clone()

        scale = max_val / qmax

        q = torch.round(weights / scale)
        q = torch.clamp(q, qmin, qmax)

        return q * scale

# %%
############################################################
# UNIFORM 8-BIT QUANTIZATION
############################################################

import copy
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

############################################################
# LOAD BEST MODEL
############################################################

base_model = PCA_CNN().to(device)

base_model.load_state_dict(
    torch.load("Models/best_model_40_24_48.pth")
)

base_model.eval()

############################################################
# CREATE UNIFORM 8-BIT MODEL
############################################################

uniform8_model = copy.deepcopy(base_model)

with torch.no_grad():

    for name, param in uniform8_model.named_parameters():

        if "weight" in name:

            param.data = quantize_weights(
                param.data,
                bits=8
            )

############################################################
# EVALUATE
############################################################

uniform8_model.eval()

y_true = []
y_pred = []

with torch.no_grad():

    for x, y in test_loader:

        x = x.to(device)

        outputs = uniform8_model(x)

        preds = outputs.argmax(1)

        y_true.extend(y.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

acc = 100 * np.mean(
    np.array(y_true) ==
    np.array(y_pred)
)

print("="*60)
print("UNIFORM 8-BIT QUANTIZATION")
print("="*60)
print(f"Accuracy = {acc:.4f}%")

print("\nConfusion Matrix")
print(confusion_matrix(y_true, y_pred))

print("\nClassification Report")
print(classification_report(y_true, y_pred))
# Out:
# ============================================================
# UNIFORM 8-BIT QUANTIZATION
# ============================================================
# Accuracy = 93.4286%
#
# Confusion Matrix
# [[521   1   1   0   0   2]
#  [  0 500   2   0   8  15]
#  [  0   1 518   3   0   3]
#  [  2   0   8 480  34   1]
#  [  0   9   4  17 466  29]
#  [  1  23   2   2  39 458]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       525
#            1       0.94      0.95      0.94       525
#            2       0.97      0.99      0.98       525
#            3       0.96      0.91      0.93       525
#            4       0.85      0.89      0.87       525
#            5       0.90      0.87      0.89       525
#
#     accuracy                           0.93      3150
#    macro avg       0.93      0.93      0.93      3150
# weighted avg       0.93      0.93      0.93      3150

# %%
############################################################
# UNIFORM 6-BIT QUANTIZATION
############################################################

import copy
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

base_model = PCA_CNN().to(device)

base_model.load_state_dict(
    torch.load("Models/best_model_40_24_48.pth")
)

base_model.eval()

uniform6_model = copy.deepcopy(base_model)

with torch.no_grad():

    for name, param in uniform6_model.named_parameters():

        if "weight" in name:

            param.data = quantize_weights(
                param.data,
                bits=6
            )

uniform6_model.eval()

y_true = []
y_pred = []

with torch.no_grad():

    for x, y in test_loader:

        x = x.to(device)

        outputs = uniform6_model(x)

        preds = outputs.argmax(1)

        y_true.extend(y.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

acc = 100*np.mean(
    np.array(y_true)==
    np.array(y_pred)
)

print("="*60)
print("UNIFORM 6-BIT QUANTIZATION")
print("="*60)
print(f"Accuracy = {acc:.4f}%")

print("\nConfusion Matrix")
print(confusion_matrix(y_true,y_pred))

print("\nClassification Report")
print(classification_report(y_true,y_pred))
# Out:
# ============================================================
# UNIFORM 6-BIT QUANTIZATION
# ============================================================
# Accuracy = 93.3333%
#
# Confusion Matrix
# [[520   1   1   0   0   3]
#  [  0 490   2   0  15  18]
#  [  0   1 520   1   1   2]
#  [  2   0   9 458  55   1]
#  [  0   5   4   6 497  13]
#  [  1  23   2   2  42 455]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       525
#            1       0.94      0.93      0.94       525
#            2       0.97      0.99      0.98       525
#            3       0.98      0.87      0.92       525
#            4       0.81      0.95      0.88       525
#            5       0.92      0.87      0.89       525
#
#     accuracy                           0.93      3150
#    macro avg       0.94      0.93      0.93      3150
# weighted avg       0.94      0.93      0.93      3150

# %%
############################################################
# LAYER-WISE QUANTIZATION SENSITIVITY
############################################################

import copy



def evaluate_model(model):

    model.eval()

    correct = 0
    total = 0

    with torch.no_grad():

        for x, y in test_loader:

            x = x.to(device)
            y = y.to(device)

            outputs = model(x)

            preds = outputs.argmax(1)

            correct += (preds == y).sum().item()
            total += y.size(0)

    return 100.0 * correct / total


############################################################
# LOAD BEST MODEL
############################################################

base_model = PCA_CNN().to(device)

base_model.load_state_dict(
    torch.load("Models/best_model_40_24_48.pth")
)

baseline_acc = evaluate_model(base_model)

print(f"\nBaseline Accuracy = {baseline_acc:.4f}%")
# Out:
# Baseline Accuracy = 93.4921%

# %%
############################################################
# TEST EACH LAYER
############################################################

layers_to_test = [
    "conv1.weight",
    "conv2.weight",
    "fc1.weight",
    "fc2.weight"
]

bitwidths = [8, 6, 4, 2]

results = {}

for layer_name in layers_to_test:

    results[layer_name] = {}

    print("\n" + "="*60)
    print("Testing:", layer_name)

    for bits in bitwidths:

        model = copy.deepcopy(base_model)

        with torch.no_grad():

            for name, param in model.named_parameters():

                if name == layer_name:

                    param.data = quantize_weights(
                        param.data,
                        bits
                    )

        acc = evaluate_model(model)

        results[layer_name][bits] = acc

        print(
            f"{bits:2d}-bit --> {acc:.4f}%"
        )
# Out:
# ============================================================
# Testing: conv1.weight
#  8-bit --> 93.5238%
#  6-bit --> 93.5556%
#  4-bit --> 93.1111%
#  2-bit --> 64.7619%
#
# ============================================================
# Testing: conv2.weight
#  8-bit --> 93.4603%
#  6-bit --> 93.3016%
#  4-bit --> 92.0952%
#  2-bit --> 24.2222%
#
# ============================================================
# Testing: fc1.weight
#  8-bit --> 93.5238%
#  6-bit --> 93.6508%
#  4-bit --> 92.6349%
#  2-bit --> 46.6667%
#
# ============================================================
# Testing: fc2.weight
#  8-bit --> 93.5238%
#  6-bit --> 93.0159%
#  4-bit --> 74.1270%
#  2-bit --> 43.3333%

# %%
############################################################
# PRINT TABLE
############################################################

print("\n")
print("="*70)
print("HAQ SENSITIVITY TABLE")
print("="*70)

for layer, vals in results.items():

    print(
        f"{layer:15s}",
        end=""
    )

    for bits in [8,6,4,2]:

        print(
            f"{vals[bits]:8.2f}",
            end=""
        )

    print()

print("\nColumns = [8bit 6bit 4bit 2bit]")
# Out:
# ======================================================================
# HAQ SENSITIVITY TABLE
# ======================================================================
# conv1.weight      93.52   93.56   93.11   64.76
# conv2.weight      93.46   93.30   92.10   24.22
# fc1.weight        93.52   93.65   92.63   46.67
# fc2.weight        93.52   93.02   74.13   43.33
#
# Columns = [8bit 6bit 4bit 2bit]

# %%
############################################################
# EXHAUSTIVE MIXED-PRECISION SEARCH
############################################################

import copy
import itertools
import pandas as pd

layers = [
    "conv1.weight",
    "conv2.weight",
    "fc1.weight",
    "fc2.weight"
]

bit_choices = [8, 6, 4]

results = []

total = len(bit_choices) ** len(layers)

count = 1

for bits in itertools.product(bit_choices, repeat=4):

    print(f"Testing {count}/{total} : {bits}")

    model = copy.deepcopy(base_model)

    with torch.no_grad():

        for name, param in model.named_parameters():

            if name in layers:

                idx = layers.index(name)

                param.data = quantize_weights(
                    param.data,
                    bits[idx]
                )

    ########################################################
    # EVALUATE
    ########################################################

    acc = evaluate_model(model)

    ########################################################
    # DEBUG FOR (8,8,8,8)
    ########################################################

    if bits == (8, 8, 8, 8):

        print("\nUniform from exhaustive search =", acc)

        print("\nWeight sums:")

        for name, param in model.named_parameters():

            if "weight" in name:

                print(name, torch.sum(param).item())

    ########################################################
    # SAVE RESULT
    ########################################################

    results.append({
        "Conv1": bits[0],
        "Conv2": bits[1],
        "FC1": bits[2],
        "FC2": bits[3],
        "Accuracy": acc
    })

    count += 1

############################################################
# CREATE DATAFRAME
############################################################

results_df = pd.DataFrame(results)

print("\nNumber of results:", len(results))

print("\n(8,8,8,8) row:")

print(
    results_df[
        (results_df["Conv1"] == 8) &
        (results_df["Conv2"] == 8) &
        (results_df["FC1"] == 8) &
        (results_df["FC2"] == 8)
    ]
)
# Out:
# Testing 1/81 : (8, 8, 8, 8)
#
# Uniform from exhaustive search = 93.42857142857143
#
# Weight sums:
# conv1.weight 6.335740566253662
# conv2.weight -71.75250244140625
# fc1.weight -46.760459899902344
# fc2.weight -73.09268188476562
# Testing 2/81 : (8, 8, 8, 6)
# Testing 3/81 : (8, 8, 8, 4)
# Testing 4/81 : (8, 8, 6, 8)
# Testing 5/81 : (8, 8, 6, 6)
# Testing 6/81 : (8, 8, 6, 4)
# Testing 7/81 : (8, 8, 4, 8)
# Testing 8/81 : (8, 8, 4, 6)
# Testing 9/81 : (8, 8, 4, 4)
# Testing 10/81 : (8, 6, 8, 8)
# Testing 11/81 : (8, 6, 8, 6)
# Testing 12/81 : (8, 6, 8, 4)
# Testing 13/81 : (8, 6, 6, 8)
# Testing 14/81 : (8, 6, 6, 6)
# Testing 15/81 : (8, 6, 6, 4)
# Testing 16/81 : (8, 6, 4, 8)
# Testing 17/81 : (8, 6, 4, 6)
# Testing 18/81 : (8, 6, 4, 4)
# Testing 19/81 : (8, 4, 8, 8)
# Testing 20/81 : (8, 4, 8, 6)
# Testing 21/81 : (8, 4, 8, 4)
# Testing 22/81 : (8, 4, 6, 8)
# Testing 23/81 : (8, 4, 6, 6)
# Testing 24/81 : (8, 4, 6, 4)
# Testing 25/81 : (8, 4, 4, 8)
# Testing 26/81 : (8, 4, 4, 6)
# Testing 27/81 : (8, 4, 4, 4)
# Testing 28/81 : (6, 8, 8, 8)
# Testing 29/81 : (6, 8, 8, 6)
# Testing 30/81 : (6, 8, 8, 4)
# Testing 31/81 : (6, 8, 6, 8)
# Testing 32/81 : (6, 8, 6, 6)
# Testing 33/81 : (6, 8, 6, 4)
# Testing 34/81 : (6, 8, 4, 8)
# Testing 35/81 : (6, 8, 4, 6)
# Testing 36/81 : (6, 8, 4, 4)
# Testing 37/81 : (6, 6, 8, 8)
# Testing 38/81 : (6, 6, 8, 6)
# Testing 39/81 : (6, 6, 8, 4)
# Testing 40/81 : (6, 6, 6, 8)
# Testing 41/81 : (6, 6, 6, 6)
# Testing 42/81 : (6, 6, 6, 4)
# Testing 43/81 : (6, 6, 4, 8)
# Testing 44/81 : (6, 6, 4, 6)
# Testing 45/81 : (6, 6, 4, 4)
# Testing 46/81 : (6, 4, 8, 8)
# Testing 47/81 : (6, 4, 8, 6)
# Testing 48/81 : (6, 4, 8, 4)
# Testing 49/81 : (6, 4, 6, 8)
# Testing 50/81 : (6, 4, 6, 6)
# Testing 51/81 : (6, 4, 6, 4)
# Testing 52/81 : (6, 4, 4, 8)
# Testing 53/81 : (6, 4, 4, 6)
# Testing 54/81 : (6, 4, 4, 4)
# Testing 55/81 : (4, 8, 8, 8)
# Testing 56/81 : (4, 8, 8, 6)
# Testing 57/81 : (4, 8, 8, 4)
# Testing 58/81 : (4, 8, 6, 8)
# Testing 59/81 : (4, 8, 6, 6)
# Testing 60/81 : (4, 8, 6, 4)
# Testing 61/81 : (4, 8, 4, 8)
# Testing 62/81 : (4, 8, 4, 6)
# Testing 63/81 : (4, 8, 4, 4)
# Testing 64/81 : (4, 6, 8, 8)
# Testing 65/81 : (4, 6, 8, 6)
# Testing 66/81 : (4, 6, 8, 4)
# Testing 67/81 : (4, 6, 6, 8)
# Testing 68/81 : (4, 6, 6, 6)
# Testing 69/81 : (4, 6, 6, 4)
# Testing 70/81 : (4, 6, 4, 8)
# Testing 71/81 : (4, 6, 4, 6)
# Testing 72/81 : (4, 6, 4, 4)
# Testing 73/81 : (4, 4, 8, 8)
# Testing 74/81 : (4, 4, 8, 6)
# Testing 75/81 : (4, 4, 8, 4)
# Testing 76/81 : (4, 4, 6, 8)
# Testing 77/81 : (4, 4, 6, 6)
# Testing 78/81 : (4, 4, 6, 4)
# Testing 79/81 : (4, 4, 4, 8)
# Testing 80/81 : (4, 4, 4, 6)
# Testing 81/81 : (4, 4, 4, 4)
#
# Number of results: 81
#
# (8,8,8,8) row:
#    Conv1  Conv2  FC1  FC2   Accuracy
# 0      8      8    8    8  93.428571

# %%
for name, param in base_model.named_parameters():
    print(name)
# Out:
# conv1.weight
# conv1.bias
# conv2.weight
# conv2.bias
# fc1.weight
# fc1.bias
# fc2.weight
# fc2.bias

# %%
############################################################
# CREATE TABLE
############################################################

results_df = pd.DataFrame(
    results,
    columns=[
        "Conv1",
        "Conv2",
        "FC1",
        "FC2",
        "Accuracy"
    ]
)

results_df = results_df.sort_values(
    by="Accuracy",
    ascending=False
)

results_df = results_df.reset_index(drop=True)

print(results_df)
# Out:
#     Conv1  Conv2  FC1  FC2   Accuracy
# 0       8      8    6    8  93.682540
# 1       6      6    6    8  93.682540
# 2       6      8    6    8  93.650794
# 3       6      8    8    8  93.587302
# 4       8      6    6    8  93.555556
# ..    ...    ...  ...  ...        ...
# 76      4      8    4    4  73.460317
# 77      4      6    8    4  73.047619
# 78      4      8    8    4  72.698413
# 79      4      6    6    4  72.571429
# 80      4      8    6    4  72.444444
#
# [81 rows x 5 columns]

# %%
results_df.to_csv(
    "Mixed_Quantization_Results.csv",
    index=False
)

print("Saved Successfully")
# Out:
# Saved Successfully

# %%
############################################################
# HARDWARE COST ANALYSIS
############################################################

import numpy as np

PARAMS = {
    "Conv1":416,
    "Conv2":2080,
    "FC1":2112,
    "FC2":390
}

# FP32 reference
FP32_BITS = (
    (PARAMS["Conv1"] +
     PARAMS["Conv2"] +
     PARAMS["FC1"] +
     PARAMS["FC2"]) * 32
)

# Calculate hardware cost
results_df["Memory(bits)"] = (
    results_df["Conv1"] * PARAMS["Conv1"] +
    results_df["Conv2"] * PARAMS["Conv2"] +
    results_df["FC1"]   * PARAMS["FC1"] +
    results_df["FC2"]   * PARAMS["FC2"]
)

results_df["Memory(KB)"] = (
    results_df["Memory(bits)"] / 8 / 1024
)

results_df["Compression"] = (
    FP32_BITS / results_df["Memory(bits)"]
)

# Xilinx BRAM18 = 18 Kbits = 18432 bits
results_df["BRAM18"] = np.ceil(
    results_df["Memory(bits)"] / 18432
).astype(int)

############################################################
# KEEP ONLY GOOD MODELS
############################################################

good_models = results_df[
    results_df["Accuracy"] >= 93.0
].copy()

good_models = good_models.sort_values(
    by=["Accuracy", "Memory(bits)"],
    ascending=[False, True]
)

good_models = good_models.reset_index(drop=True)

print(good_models)
# Out:
#     Conv1  Conv2  FC1  FC2   Accuracy  Memory(bits)  Memory(KB)  Compression  \
# 0       6      6    6    8  93.682540         30768    3.755859     5.198128
# 1       8      8    6    8  93.682540         35760    4.365234     4.472483
# 2       6      8    6    8  93.650794         34928    4.263672     4.579020
# 3       6      8    8    8  93.587302         39152    4.779297     4.085002
# 4       8      6    6    8  93.555556         31600    3.857422     5.061266
# 5       4      8    6    8  93.428571         34096    4.162109     4.690756
# 6       6      6    8    8  93.428571         34992    4.271484     4.570645
# 7       8      8    8    8  93.428571         39984    4.880859     4.000000
# 8       8      6    6    6  93.365079         30820    3.762207     5.189358
# 9       6      6    6    6  93.333333         29988    3.660645     5.333333
# 10      4      8    8    8  93.301587         38320    4.677734     4.173695
# 11      8      6    8    8  93.269841         35824    4.373047     4.464493
# 12      8      8    6    6  93.174603         34980    4.270020     4.572213
# 13      4      6    6    8  93.142857         29936    3.654297     5.342598
# 14      6      8    8    6  93.111111         38372    4.684082     4.168039
# 15      6      8    6    6  93.079365         34148    4.168457     4.683613
# 16      8      8    8    6  93.079365         39204    4.785645     4.079584
#
#     BRAM18
# 0        2
# 1        2
# 2        2
# 3        3
# 4        2
# 5        2
# 6        2
# 7        3
# 8        2
# 9        2
# 10       3
# 11       2
# 12       2
# 13       2
# 14       3
# 15       2
# 16       3

# %%
############################################################
# SAVE RESULTS
############################################################

good_models.to_csv(
    "Hardware_Aware_Results.csv",
    index=False
)

print("Saved Successfully!")

print("\nTop Hardware-Aware Models\n")
print(good_models)
# Out:
# Saved Successfully!
#
# Top Hardware-Aware Models
#
#     Conv1  Conv2  FC1  FC2   Accuracy  Memory(bits)  Memory(KB)  Compression  \
# 0       6      6    6    8  93.682540         30768    3.755859     5.198128
# 1       8      8    6    8  93.682540         35760    4.365234     4.472483
# 2       6      8    6    8  93.650794         34928    4.263672     4.579020
# 3       6      8    8    8  93.587302         39152    4.779297     4.085002
# 4       8      6    6    8  93.555556         31600    3.857422     5.061266
# 5       4      8    6    8  93.428571         34096    4.162109     4.690756
# 6       6      6    8    8  93.428571         34992    4.271484     4.570645
# 7       8      8    8    8  93.428571         39984    4.880859     4.000000
# 8       8      6    6    6  93.365079         30820    3.762207     5.189358
# 9       6      6    6    6  93.333333         29988    3.660645     5.333333
# 10      4      8    8    8  93.301587         38320    4.677734     4.173695
# 11      8      6    8    8  93.269841         35824    4.373047     4.464493
# 12      8      8    6    6  93.174603         34980    4.270020     4.572213
# 13      4      6    6    8  93.142857         29936    3.654297     5.342598
# 14      6      8    8    6  93.111111         38372    4.684082     4.168039
# 15      6      8    6    6  93.079365         34148    4.168457     4.683613
# 16      8      8    8    6  93.079365         39204    4.785645     4.079584
#
#     BRAM18
# 0        2
# 1        2
# 2        2
# 3        3
# 4        2
# 5        2
# 6        2
# 7        3
# 8        2
# 9        2
# 10       3
# 11       2
# 12       2
# 13       2
# 14       3
# 15       2
# 16       3

# %%
print("Conv1 :", model.conv1.weight.numel())
print("Conv2 :", model.conv2.weight.numel())
print("FC1   :", model.fc1.weight.numel())
print("FC2   :", model.fc2.weight.numel())
# Out:
# Conv1 : 480
# Conv2 : 1920
# FC1   : 1152
# FC2   : 288

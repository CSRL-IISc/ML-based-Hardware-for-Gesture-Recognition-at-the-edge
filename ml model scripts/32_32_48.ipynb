# %%
import os
import json
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import random

SEED = 42

random.seed(SEED)
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from sklearn.decomposition import PCA

# %%
import os

os.makedirs("Models", exist_ok=True)

print("Models folder is ready.")
# Out:
# Models folder is ready.

# %%
############################################################
# CONFIG
############################################################

TRAIN_DIR = "/kaggle/input/datasets/vikas635233/dataset-for-train-test/EMG-EPN612 Dataset/trainingJSON"
TEST_DIR = "/kaggle/input/datasets/vikas635233/dataset-for-train-test/EMG-EPN612 Dataset/testingJSON"

TARGET_LEN = 1019
PCA_COMPONENTS = 6

BATCH_SIZE = 32
EPOCHS = 200
LR = 1e-3

############################################################
# LABEL MAP
############################################################

LABEL_MAP = {
    "noGesture": 0,
    "fist": 1,
    "waveIn": 2,
    "waveOut": 3,
    "open": 4,
    "pinch": 5
}

############################################################
# PAD / CROP
############################################################

def pad_or_crop(signal, target_len=TARGET_LEN):

    current_len = signal.shape[1]

    if current_len > target_len:

        signal = signal[:, :target_len]

    elif current_len < target_len:

        pad = target_len - current_len

        signal = np.pad(
            signal,
            ((0, 0), (0, pad)),
            mode='constant'
        )

    return signal

############################################################
# LOAD DATA
############################################################

def load_dataset(folder, allowed_users=None):



    X = []
    y = []

    for root, dirs, files in os.walk(folder):

 

        user_name = os.path.basename(root)

        if allowed_users is not None:
            if user_name not in allowed_users:
               
                continue

        for file in files:

            if not file.endswith(".json"):
                continue

            path = os.path.join(root, file)

        

            with open(path, "r") as f:
                data = json.load(f)

         

            if "trainingSamples" not in data:
               
                continue

            samples = data["trainingSamples"]

           
            for key in samples:

                sample = samples[key]

                gesture = sample["gestureName"]

                if gesture not in LABEL_MAP:
                    
                    continue

                emg = sample["emg"]

                signal = np.array([
                    emg["ch1"],
                    emg["ch2"],
                    emg["ch3"],
                    emg["ch4"],
                    emg["ch5"],
                    emg["ch6"],
                    emg["ch7"],
                    emg["ch8"]
                ], dtype=np.float32)

                signal = pad_or_crop(signal)

                X.append(signal)
                y.append(LABEL_MAP[gesture])


    return np.array(X, dtype=np.float32), np.array(y)

############################################################
# PCA
############################################################

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

def apply_pca(X_train, X_test):

    scaler = StandardScaler()

    pca = PCA(
        n_components=PCA_COMPONENTS
    )

    temp = X_train.transpose(0,2,1)
    temp = temp.reshape(-1,8)

    temp = scaler.fit_transform(temp)

    pca.fit(temp)

    train_out = []

    for sample in X_train:

        sample = sample.T
        sample = scaler.transform(sample)
        sample = pca.transform(sample)
        sample = sample.T

        train_out.append(sample)

    test_out = []

    for sample in X_test:

        sample = sample.T
        sample = scaler.transform(sample)
        sample = pca.transform(sample)
        sample = sample.T

        test_out.append(sample)

    return (
        np.array(train_out, dtype=np.float32),
        np.array(test_out, dtype=np.float32)
    )

# %%
############################################################
# DATASET
############################################################

class EMGDataset(Dataset):

    def __init__(self, X, y):

        self.X = torch.tensor(
            X,
            dtype=torch.float32
        )

        self.y = torch.tensor(
            y,
            dtype=torch.long
        )

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

############################################################
# CNN MODEL
############################################################

# %%
############################################################
# CNN MODEL
############################################################

class PCA_CNN(nn.Module):

    def __init__(self):

        super().__init__()

        ############################################################
        # Conv1
        ############################################################

        self.conv1 = nn.Conv1d(
            in_channels=6,
            out_channels=32,
            kernel_size=2
        )

        self.pool = nn.MaxPool1d(
            kernel_size=2
        )

        ############################################################
        # Conv2 (64 -> 52 filters)
        ############################################################

        self.conv2 = nn.Conv1d(
            in_channels=32,
            out_channels=32,
            kernel_size=2
        )

        ############################################################
        # GAP
        ############################################################

        self.gap = nn.AdaptiveAvgPool1d(1)

        ############################################################
        # FC
        ############################################################

        self.fc1 = nn.Linear(
            32,
            48
        )

        self.fc2 = nn.Linear(
            48,
            6
        )

    def forward(self, x):

        x = self.conv1(x)
        x = F.relu(x)

        x = self.pool(x)

        x = self.conv2(x)
        x = F.relu(x)

        x = self.gap(x)

        x = x.squeeze(-1)

        x = self.fc1(x)
        x = F.relu(x)

        x = self.fc2(x)

        return x

# %%
model = PCA_CNN()
print(model)

print("Parameters:",
      sum(p.numel() for p in model.parameters()))
# Out:
# PCA_CNN(
#   (conv1): Conv1d(6, 32, kernel_size=(2,), stride=(1,))
#   (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#   (gap): AdaptiveAvgPool1d(output_size=1)
#   (fc1): Linear(in_features=32, out_features=48, bias=True)
#   (fc2): Linear(in_features=48, out_features=6, bias=True)
# )
# Parameters: 4374

# %%
############################################################
# LOAD DATA
############################################################
TEST_USERS = [
    "user1","user2","user3","user4","user5",
    "user6","user7","user8","user9","user10",
    "user11","user12","user13","user14","user15",
    "user16","user17","user18","user19","user20",
    "user21"
]
print("Loading data...")

print("TRAIN_DIR =", TRAIN_DIR)
print("TEST_DIR  =", TEST_DIR)

X_train, y_train = load_dataset(TRAIN_DIR)

X_test, y_test = load_dataset(
    TEST_DIR,
    TEST_USERS
)

print("Train shape:", X_train.shape)
print("Test shape :", X_test.shape)

print("X_train:", X_train.shape)
print("y_train:", y_train.shape)

print("X_test :", X_test.shape)
print("y_test :", y_test.shape)

print("Train distribution:")
print(np.unique(y_train, return_counts=True))

print("Test distribution:")
print(np.unique(y_test, return_counts=True))

############################################################
# PCA
############################################################

print("Applying PCA...")

X_train, X_test = apply_pca(
    X_train,
    X_test
)

np.save("X_train_pca.npy", X_train)
np.save("y_train.npy", y_train)

np.save("X_test_pca.npy", X_test)
np.save("y_test.npy", y_test)

print("After PCA")

print("Train :", X_train.shape)
print("Test  :", X_test.shape)

############################################################
# DATALOADER
############################################################

train_dataset = EMGDataset(
    X_train,
    y_train
)

test_dataset = EMGDataset(
    X_test,
    y_test
)

train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False
)
# Out:
# Loading data...
# TRAIN_DIR = /kaggle/input/datasets/vikas635233/dataset-for-train-test/EMG-EPN612 Dataset/trainingJSON
# TEST_DIR  = /kaggle/input/datasets/vikas635233/dataset-for-train-test/EMG-EPN612 Dataset/testingJSON
# Train shape: (45900, 8, 1019)
# Test shape : (3150, 8, 1019)
# X_train: (45900, 8, 1019)
# y_train: (45900,)
# X_test : (3150, 8, 1019)
# y_test : (3150,)
# Train distribution:
# (array([0, 1, 2, 3, 4, 5]), array([7650, 7650, 7650, 7650, 7650, 7650]))
# Test distribution:
# (array([0, 1, 2, 3, 4, 5]), array([525, 525, 525, 525, 525, 525]))
# Applying PCA...
# After PCA
# Train : (45900, 6, 1019)
# Test  : (3150, 6, 1019)

# %%
############################################################
# DEVICE
############################################################

device = torch.device(
    "cuda" if torch.cuda.is_available()
    else "cpu"
)

print("Device:", device)

############################################################
# MODEL
############################################################

model = PCA_CNN().to(device)

total_params = sum(p.numel() for p in model.parameters())
print("Total Parameters:", total_params)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=LR
)

############################################################
# TRAIN
############################################################

best_acc = 0

for epoch in range(EPOCHS):

    ########################################################
    # TRAIN
    ########################################################

    model.train()

    train_loss = 0
    train_correct = 0
    train_total = 0

    for x, y in train_loader:

        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad()

        outputs = model(x)

        loss = criterion(
            outputs,
            y
        )

        loss.backward()

        optimizer.step()

        train_loss += loss.item()

        preds = outputs.argmax(1)

        train_total += y.size(0)

        train_correct += (
            preds == y
        ).sum().item()

    train_acc = (
        100.0 *
        train_correct /
        train_total
    )

    ########################################################
    # TEST
    ########################################################

    model.eval()

    test_correct = 0
    test_total = 0

    with torch.no_grad():

        for x, y in test_loader:

            x = x.to(device)
            y = y.to(device)

            outputs = model(x)

            preds = outputs.argmax(1)

            test_total += y.size(0)

            test_correct += (
                preds == y
            ).sum().item()

    test_acc = (
        100.0 *
        test_correct /
        test_total
    )

    ########################################################
    # PRINT RESULTS
    ########################################################

    print(
        f"Epoch {epoch+1:03d} | "
        f"Loss {train_loss:.4f} | "
        f"Train Acc {train_acc:.2f}% | "
        f"Test Acc {test_acc:.2f}%"
    )

    ########################################################
    # SAVE BEST MODEL
    ########################################################

    if test_acc > best_acc:

        best_acc = test_acc

        torch.save(
    model.state_dict(),
    "Models/best_model_32_32_48.pth"
)

        print(
            f"Saved model : {best_acc:.2f}%"
        )

print("\nTraining Complete")
print("Best Test Accuracy =", best_acc)
# Out:
# Device: cuda
# Total Parameters: 4374
# Epoch 001 | Loss 1296.6847 | Train Acc 65.75% | Test Acc 83.65%
# Saved model : 83.65%
# Epoch 002 | Loss 742.1431 | Train Acc 81.94% | Test Acc 87.40%
# Saved model : 87.40%
# Epoch 003 | Loss 639.8905 | Train Acc 84.27% | Test Acc 88.95%
# Saved model : 88.95%
# Epoch 004 | Loss 589.1542 | Train Acc 85.20% | Test Acc 89.49%
# Saved model : 89.49%
# Epoch 005 | Loss 551.9292 | Train Acc 86.14% | Test Acc 89.14%
# Epoch 006 | Loss 520.6141 | Train Acc 86.72% | Test Acc 90.86%
# Saved model : 90.86%
# Epoch 007 | Loss 494.3016 | Train Acc 87.42% | Test Acc 90.06%
# Epoch 008 | Loss 470.2828 | Train Acc 88.08% | Test Acc 91.40%
# Saved model : 91.40%
# Epoch 009 | Loss 447.4441 | Train Acc 88.69% | Test Acc 92.16%
# Saved model : 92.16%
# Epoch 010 | Loss 431.1228 | Train Acc 89.17% | Test Acc 92.60%
# Saved model : 92.60%
# Epoch 011 | Loss 416.9026 | Train Acc 89.59% | Test Acc 92.32%
# Epoch 012 | Loss 403.4660 | Train Acc 89.81% | Test Acc 92.06%
# Epoch 013 | Loss 392.6502 | Train Acc 90.05% | Test Acc 91.46%
# Epoch 014 | Loss 384.4917 | Train Acc 90.37% | Test Acc 92.67%
# Saved model : 92.67%
# Epoch 015 | Loss 377.4875 | Train Acc 90.55% | Test Acc 92.38%
# Epoch 016 | Loss 367.4831 | Train Acc 90.76% | Test Acc 92.16%
# Epoch 017 | Loss 364.0534 | Train Acc 90.91% | Test Acc 92.63%
# Epoch 018 | Loss 354.5700 | Train Acc 91.08% | Test Acc 93.27%
# Saved model : 93.27%
# Epoch 019 | Loss 346.3306 | Train Acc 91.34% | Test Acc 91.49%
# Epoch 020 | Loss 340.6064 | Train Acc 91.50% | Test Acc 93.56%
# Saved model : 93.56%
# Epoch 021 | Loss 335.3550 | Train Acc 91.63% | Test Acc 92.70%
# Epoch 022 | Loss 330.3781 | Train Acc 91.74% | Test Acc 92.29%
# Epoch 023 | Loss 327.1371 | Train Acc 91.83% | Test Acc 93.97%
# Saved model : 93.97%
# Epoch 024 | Loss 317.1524 | Train Acc 92.02% | Test Acc 93.33%
# Epoch 025 | Loss 313.1200 | Train Acc 92.15% | Test Acc 93.71%
# Epoch 026 | Loss 309.7915 | Train Acc 92.15% | Test Acc 93.33%
# Epoch 027 | Loss 305.5361 | Train Acc 92.41% | Test Acc 92.00%
# Epoch 028 | Loss 303.5495 | Train Acc 92.42% | Test Acc 93.71%
# Epoch 029 | Loss 295.8032 | Train Acc 92.60% | Test Acc 93.90%
# Epoch 030 | Loss 292.7490 | Train Acc 92.65% | Test Acc 94.38%
# Saved model : 94.38%
# Epoch 031 | Loss 288.8562 | Train Acc 92.70% | Test Acc 92.19%
# Epoch 032 | Loss 283.9266 | Train Acc 92.90% | Test Acc 93.84%
# Epoch 033 | Loss 280.5706 | Train Acc 93.00% | Test Acc 93.43%
# Epoch 034 | Loss 278.4962 | Train Acc 92.97% | Test Acc 93.11%
# Epoch 035 | Loss 274.4210 | Train Acc 93.08% | Test Acc 92.73%
# Epoch 036 | Loss 268.9046 | Train Acc 93.25% | Test Acc 93.62%
# Epoch 037 | Loss 263.2601 | Train Acc 93.38% | Test Acc 93.30%
# Epoch 038 | Loss 264.3413 | Train Acc 93.46% | Test Acc 93.78%
# Epoch 039 | Loss 259.5440 | Train Acc 93.41% | Test Acc 92.98%
# Epoch 040 | Loss 255.0177 | Train Acc 93.53% | Test Acc 93.33%
# Epoch 041 | Loss 252.2505 | Train Acc 93.70% | Test Acc 93.87%
# Epoch 042 | Loss 248.9168 | Train Acc 93.79% | Test Acc 93.33%
# Epoch 043 | Loss 243.9348 | Train Acc 93.88% | Test Acc 93.78%
# Epoch 044 | Loss 241.8059 | Train Acc 93.92% | Test Acc 92.95%
# Epoch 045 | Loss 238.7519 | Train Acc 94.06% | Test Acc 93.71%
# Epoch 046 | Loss 237.7624 | Train Acc 94.07% | Test Acc 94.00%
# Epoch 047 | Loss 234.6052 | Train Acc 94.13% | Test Acc 92.92%
# Epoch 048 | Loss 230.4556 | Train Acc 94.25% | Test Acc 93.11%
# Epoch 049 | Loss 227.6469 | Train Acc 94.35% | Test Acc 93.87%
# Epoch 050 | Loss 225.6705 | Train Acc 94.37% | Test Acc 93.90%
# Epoch 051 | Loss 224.5315 | Train Acc 94.42% | Test Acc 93.37%
# Epoch 052 | Loss 223.5119 | Train Acc 94.41% | Test Acc 93.21%
# Epoch 053 | Loss 215.8021 | Train Acc 94.58% | Test Acc 94.06%
# Epoch 054 | Loss 216.9403 | Train Acc 94.56% | Test Acc 93.81%
# Epoch 055 | Loss 214.5430 | Train Acc 94.60% | Test Acc 93.75%
# Epoch 056 | Loss 213.7405 | Train Acc 94.61% | Test Acc 94.10%
# Epoch 057 | Loss 211.6424 | Train Acc 94.73% | Test Acc 93.59%
# Epoch 058 | Loss 208.1613 | Train Acc 94.74% | Test Acc 94.19%
# Epoch 059 | Loss 207.0775 | Train Acc 94.76% | Test Acc 94.06%
# Epoch 060 | Loss 205.2851 | Train Acc 94.87% | Test Acc 93.17%
# Epoch 061 | Loss 203.3008 | Train Acc 94.90% | Test Acc 93.87%
# Epoch 062 | Loss 201.5157 | Train Acc 94.95% | Test Acc 94.06%
# Epoch 063 | Loss 199.1514 | Train Acc 94.90% | Test Acc 93.68%
# Epoch 064 | Loss 198.3694 | Train Acc 94.95% | Test Acc 94.25%
# Epoch 065 | Loss 196.1233 | Train Acc 94.99% | Test Acc 93.21%
# Epoch 066 | Loss 195.2572 | Train Acc 95.10% | Test Acc 94.16%
# Epoch 067 | Loss 195.1266 | Train Acc 95.08% | Test Acc 93.46%
# Epoch 068 | Loss 194.0520 | Train Acc 95.17% | Test Acc 93.30%
# Epoch 069 | Loss 192.1249 | Train Acc 95.15% | Test Acc 93.49%
# Epoch 070 | Loss 189.3687 | Train Acc 95.17% | Test Acc 94.06%
# Epoch 071 | Loss 188.5171 | Train Acc 95.19% | Test Acc 93.90%
# Epoch 072 | Loss 186.3276 | Train Acc 95.38% | Test Acc 93.62%
# Epoch 073 | Loss 185.2278 | Train Acc 95.34% | Test Acc 92.41%
# Epoch 074 | Loss 183.8841 | Train Acc 95.43% | Test Acc 94.13%
# Epoch 075 | Loss 182.0202 | Train Acc 95.41% | Test Acc 93.90%
# Epoch 076 | Loss 181.8736 | Train Acc 95.44% | Test Acc 93.68%
# Epoch 077 | Loss 179.3086 | Train Acc 95.54% | Test Acc 93.71%
# Epoch 078 | Loss 179.5267 | Train Acc 95.51% | Test Acc 94.10%
# Epoch 079 | Loss 178.4493 | Train Acc 95.50% | Test Acc 94.16%
# Epoch 080 | Loss 176.9420 | Train Acc 95.58% | Test Acc 92.92%
# Epoch 081 | Loss 175.1302 | Train Acc 95.63% | Test Acc 93.78%
# Epoch 082 | Loss 174.1802 | Train Acc 95.66% | Test Acc 93.49%
# Epoch 083 | Loss 172.6588 | Train Acc 95.66% | Test Acc 94.19%
# Epoch 084 | Loss 173.4839 | Train Acc 95.64% | Test Acc 93.59%
# Epoch 085 | Loss 172.5325 | Train Acc 95.66% | Test Acc 91.84%
# Epoch 086 | Loss 171.7095 | Train Acc 95.65% | Test Acc 93.37%
# Epoch 087 | Loss 165.9769 | Train Acc 95.83% | Test Acc 94.06%
# Epoch 088 | Loss 169.9984 | Train Acc 95.78% | Test Acc 93.68%
# Epoch 089 | Loss 167.8720 | Train Acc 95.73% | Test Acc 93.68%
# Epoch 090 | Loss 164.7872 | Train Acc 95.83% | Test Acc 92.92%
# Epoch 091 | Loss 166.3393 | Train Acc 95.88% | Test Acc 93.37%
# Epoch 092 | Loss 162.7480 | Train Acc 95.92% | Test Acc 93.65%
# Epoch 093 | Loss 162.7542 | Train Acc 95.91% | Test Acc 93.46%
# Epoch 094 | Loss 162.3506 | Train Acc 95.90% | Test Acc 93.43%
# Epoch 095 | Loss 161.0932 | Train Acc 95.97% | Test Acc 93.68%
# Epoch 096 | Loss 160.0788 | Train Acc 95.98% | Test Acc 92.83%
# Epoch 097 | Loss 161.1499 | Train Acc 95.87% | Test Acc 93.94%
# Epoch 098 | Loss 158.1101 | Train Acc 96.09% | Test Acc 93.49%
# Epoch 099 | Loss 158.3845 | Train Acc 95.95% | Test Acc 93.68%
# Epoch 100 | Loss 155.4216 | Train Acc 96.08% | Test Acc 93.81%
# Epoch 101 | Loss 154.3468 | Train Acc 96.10% | Test Acc 93.56%
# Epoch 102 | Loss 154.0211 | Train Acc 96.14% | Test Acc 93.02%
# Epoch 103 | Loss 153.4708 | Train Acc 96.17% | Test Acc 92.76%
# Epoch 104 | Loss 154.9152 | Train Acc 96.14% | Test Acc 93.52%
# Epoch 105 | Loss 152.0724 | Train Acc 96.12% | Test Acc 94.03%
# Epoch 106 | Loss 152.1669 | Train Acc 96.17% | Test Acc 93.30%
# Epoch 107 | Loss 151.8760 | Train Acc 96.14% | Test Acc 93.94%
# Epoch 108 | Loss 152.0549 | Train Acc 96.23% | Test Acc 93.43%
# Epoch 109 | Loss 150.1884 | Train Acc 96.25% | Test Acc 93.52%
# Epoch 110 | Loss 148.5417 | Train Acc 96.33% | Test Acc 92.92%
# Epoch 111 | Loss 149.3792 | Train Acc 96.24% | Test Acc 94.19%
# Epoch 112 | Loss 145.4823 | Train Acc 96.39% | Test Acc 93.59%
# Epoch 113 | Loss 144.6146 | Train Acc 96.37% | Test Acc 93.62%
# Epoch 114 | Loss 146.4823 | Train Acc 96.36% | Test Acc 93.62%
# Epoch 115 | Loss 143.9699 | Train Acc 96.41% | Test Acc 94.00%
# Epoch 116 | Loss 145.9180 | Train Acc 96.37% | Test Acc 92.95%
# Epoch 117 | Loss 141.8971 | Train Acc 96.39% | Test Acc 92.70%
# Epoch 118 | Loss 143.4003 | Train Acc 96.49% | Test Acc 93.49%
# Epoch 119 | Loss 141.3415 | Train Acc 96.44% | Test Acc 93.75%
# Epoch 120 | Loss 139.7367 | Train Acc 96.57% | Test Acc 93.62%
# Epoch 121 | Loss 141.3958 | Train Acc 96.44% | Test Acc 93.59%
# Epoch 122 | Loss 141.4533 | Train Acc 96.43% | Test Acc 93.75%
# Epoch 123 | Loss 136.6906 | Train Acc 96.64% | Test Acc 93.27%
# Epoch 124 | Loss 139.5706 | Train Acc 96.50% | Test Acc 93.78%
# Epoch 125 | Loss 137.0911 | Train Acc 96.53% | Test Acc 93.94%
# Epoch 126 | Loss 137.1372 | Train Acc 96.53% | Test Acc 93.75%
# Epoch 127 | Loss 137.3668 | Train Acc 96.56% | Test Acc 93.05%
# Epoch 128 | Loss 137.6025 | Train Acc 96.59% | Test Acc 93.43%
# Epoch 129 | Loss 134.6255 | Train Acc 96.66% | Test Acc 92.41%
# Epoch 130 | Loss 138.2486 | Train Acc 96.50% | Test Acc 94.00%
# Epoch 131 | Loss 135.9603 | Train Acc 96.66% | Test Acc 93.65%
# Epoch 132 | Loss 134.5469 | Train Acc 96.56% | Test Acc 93.08%
# Epoch 133 | Loss 133.0558 | Train Acc 96.69% | Test Acc 93.11%
# Epoch 134 | Loss 134.4323 | Train Acc 96.67% | Test Acc 93.40%
# Epoch 135 | Loss 133.6081 | Train Acc 96.75% | Test Acc 93.84%
# Epoch 136 | Loss 132.0113 | Train Acc 96.77% | Test Acc 93.43%
# Epoch 137 | Loss 132.5584 | Train Acc 96.69% | Test Acc 93.37%
# Epoch 138 | Loss 131.5112 | Train Acc 96.71% | Test Acc 93.05%
# Epoch 139 | Loss 129.0870 | Train Acc 96.86% | Test Acc 93.84%
# Epoch 140 | Loss 130.3229 | Train Acc 96.69% | Test Acc 93.21%
# Epoch 141 | Loss 129.6750 | Train Acc 96.75% | Test Acc 92.44%
# Epoch 142 | Loss 131.8934 | Train Acc 96.68% | Test Acc 92.98%
# Epoch 143 | Loss 129.2441 | Train Acc 96.74% | Test Acc 93.33%
# Epoch 144 | Loss 130.7930 | Train Acc 96.74% | Test Acc 93.24%
# Epoch 145 | Loss 127.6628 | Train Acc 96.90% | Test Acc 93.21%
# Epoch 146 | Loss 128.1031 | Train Acc 96.86% | Test Acc 93.81%
# Epoch 147 | Loss 125.6625 | Train Acc 96.86% | Test Acc 93.97%
# Epoch 148 | Loss 128.6013 | Train Acc 96.84% | Test Acc 93.33%
# Epoch 149 | Loss 127.7119 | Train Acc 96.90% | Test Acc 93.43%
# Epoch 150 | Loss 122.0462 | Train Acc 96.89% | Test Acc 93.52%
# Epoch 151 | Loss 123.9468 | Train Acc 96.91% | Test Acc 92.57%
# Epoch 152 | Loss 123.8861 | Train Acc 96.87% | Test Acc 93.65%
# Epoch 153 | Loss 125.2539 | Train Acc 96.88% | Test Acc 93.43%
# Epoch 154 | Loss 124.7290 | Train Acc 96.93% | Test Acc 94.10%
# Epoch 155 | Loss 122.8363 | Train Acc 96.96% | Test Acc 93.24%
# Epoch 156 | Loss 123.3085 | Train Acc 96.96% | Test Acc 94.03%
# Epoch 157 | Loss 123.3823 | Train Acc 96.96% | Test Acc 93.40%
# Epoch 158 | Loss 123.3459 | Train Acc 96.99% | Test Acc 94.00%
# Epoch 159 | Loss 121.8323 | Train Acc 97.02% | Test Acc 92.16%
# Epoch 160 | Loss 120.5926 | Train Acc 97.03% | Test Acc 92.92%
# Epoch 161 | Loss 121.0804 | Train Acc 97.02% | Test Acc 93.21%
# Epoch 162 | Loss 121.9674 | Train Acc 96.96% | Test Acc 93.68%
# Epoch 163 | Loss 122.6912 | Train Acc 96.88% | Test Acc 93.49%
# Epoch 164 | Loss 121.5984 | Train Acc 96.96% | Test Acc 93.56%
# Epoch 165 | Loss 117.8882 | Train Acc 97.07% | Test Acc 93.94%
# Epoch 166 | Loss 120.0194 | Train Acc 97.02% | Test Acc 93.65%
# Epoch 167 | Loss 117.6449 | Train Acc 97.14% | Test Acc 94.19%
# Epoch 168 | Loss 118.9575 | Train Acc 97.05% | Test Acc 93.75%
# Epoch 169 | Loss 119.7028 | Train Acc 97.05% | Test Acc 94.25%
# Epoch 170 | Loss 118.7741 | Train Acc 97.09% | Test Acc 93.62%
# Epoch 171 | Loss 121.2806 | Train Acc 96.92% | Test Acc 93.27%
# Epoch 172 | Loss 118.3683 | Train Acc 97.04% | Test Acc 93.37%
# Epoch 173 | Loss 116.5044 | Train Acc 97.14% | Test Acc 93.05%
# Epoch 174 | Loss 118.2711 | Train Acc 97.04% | Test Acc 93.21%
# Epoch 175 | Loss 116.4530 | Train Acc 97.15% | Test Acc 93.21%
# Epoch 176 | Loss 115.1758 | Train Acc 97.09% | Test Acc 93.43%
# Epoch 177 | Loss 116.3430 | Train Acc 97.08% | Test Acc 93.59%
# Epoch 178 | Loss 116.1692 | Train Acc 97.08% | Test Acc 94.10%
# Epoch 179 | Loss 114.6778 | Train Acc 97.14% | Test Acc 93.59%
# Epoch 180 | Loss 115.2288 | Train Acc 97.14% | Test Acc 93.11%
# Epoch 181 | Loss 118.4068 | Train Acc 97.11% | Test Acc 92.89%
# Epoch 182 | Loss 112.1970 | Train Acc 97.17% | Test Acc 93.59%
# Epoch 183 | Loss 115.8209 | Train Acc 97.18% | Test Acc 94.06%
# Epoch 184 | Loss 112.2121 | Train Acc 97.25% | Test Acc 93.30%
# Epoch 185 | Loss 114.9917 | Train Acc 97.11% | Test Acc 93.21%
# Epoch 186 | Loss 112.8880 | Train Acc 97.23% | Test Acc 93.33%
# Epoch 187 | Loss 110.6896 | Train Acc 97.26% | Test Acc 93.59%
# Epoch 188 | Loss 110.6603 | Train Acc 97.25% | Test Acc 93.21%
# Epoch 189 | Loss 111.5931 | Train Acc 97.16% | Test Acc 93.02%
# Epoch 190 | Loss 112.2660 | Train Acc 97.25% | Test Acc 93.49%
# Epoch 191 | Loss 110.3087 | Train Acc 97.25% | Test Acc 93.40%
# Epoch 192 | Loss 110.5214 | Train Acc 97.27% | Test Acc 93.94%
# Epoch 193 | Loss 112.3997 | Train Acc 97.21% | Test Acc 93.87%
# Epoch 194 | Loss 107.9664 | Train Acc 97.27% | Test Acc 93.46%
# Epoch 195 | Loss 109.0893 | Train Acc 97.31% | Test Acc 93.78%
# Epoch 196 | Loss 109.9734 | Train Acc 97.23% | Test Acc 93.59%
# Epoch 197 | Loss 109.2428 | Train Acc 97.26% | Test Acc 93.40%
# Epoch 198 | Loss 109.7978 | Train Acc 97.26% | Test Acc 92.98%
# Epoch 199 | Loss 108.9418 | Train Acc 97.32% | Test Acc 93.11%
# Epoch 200 | Loss 106.7508 | Train Acc 97.31% | Test Acc 93.75%
#
# Training Complete
# Best Test Accuracy = 94.38095238095238

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

model.load_state_dict(
    torch.load("Models/best_model_32_32_48.pth")
)

model.eval()

y_true = []
y_pred = []

with torch.no_grad():

    for x, y in test_loader:

        x = x.to(device)

        outputs = model(x)

        preds = outputs.argmax(1)

        y_true.extend(y.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

print("Confusion Matrix")
print(confusion_matrix(y_true, y_pred))

print("\nClassification Report")
print(classification_report(y_true, y_pred))
# Out:
# Confusion Matrix
# [[520   0   1   0   0   4]
#  [  0 497   6   0   6  16]
#  [  0   1 518   1   1   4]
#  [  2   0  10 485  27   1]
#  [  0   5   1  12 480  27]
#  [  1   5   2   4  40 473]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       525
#            1       0.98      0.95      0.96       525
#            2       0.96      0.99      0.97       525
#            3       0.97      0.92      0.94       525
#            4       0.87      0.91      0.89       525
#            5       0.90      0.90      0.90       525
#
#     accuracy                           0.94      3150
#    macro avg       0.94      0.94      0.94      3150
# weighted avg       0.94      0.94      0.94      3150

# %%
############################################################
# WEIGHT QUANTIZATION
############################################################
def quantize_weights(weights, bits):

    qmin = -(2 ** (bits - 1))
    qmax = (2 ** (bits - 1)) - 1

    # Linear layer
    if weights.ndim == 2:

        out = torch.empty_like(weights)

        for i in range(weights.size(0)):

            w = weights[i]

            max_val = w.abs().max()

            if max_val == 0:
                out[i] = w
                continue

            scale = max_val / qmax

            q = torch.round(w / scale)
            q = torch.clamp(q, qmin, qmax)

            out[i] = q * scale

        return out

    # Conv1D layer
    elif weights.ndim == 3:

        out = torch.empty_like(weights)

        for i in range(weights.size(0)):

            w = weights[i]

            max_val = w.abs().max()

            if max_val == 0:
                out[i] = w
                continue

            scale = max_val / qmax

            q = torch.round(w / scale)
            q = torch.clamp(q, qmin, qmax)

            out[i] = q * scale

        return out

    # Bias or scalar
    else:

        max_val = weights.abs().max()

        if max_val == 0:
            return weights.clone()

        scale = max_val / qmax

        q = torch.round(weights / scale)
        q = torch.clamp(q, qmin, qmax)

        return q * scale

# %%
############################################################
# UNIFORM 8-BIT QUANTIZATION
############################################################

import copy
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

############################################################
# LOAD BEST MODEL
############################################################

base_model = PCA_CNN().to(device)

base_model.load_state_dict(
    torch.load("Models/best_model_32_32_48.pth")
)

base_model.eval()

############################################################
# CREATE UNIFORM 8-BIT MODEL
############################################################

uniform8_model = copy.deepcopy(base_model)

with torch.no_grad():

    for name, param in uniform8_model.named_parameters():

        if "weight" in name:

            param.data = quantize_weights(
                param.data,
                bits=8
            )

############################################################
# EVALUATE
############################################################

uniform8_model.eval()

y_true = []
y_pred = []

with torch.no_grad():

    for x, y in test_loader:

        x = x.to(device)

        outputs = uniform8_model(x)

        preds = outputs.argmax(1)

        y_true.extend(y.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

acc = 100 * np.mean(
    np.array(y_true) ==
    np.array(y_pred)
)

print("="*60)
print("UNIFORM 8-BIT QUANTIZATION")
print("="*60)
print(f"Accuracy = {acc:.4f}%")

print("\nConfusion Matrix")
print(confusion_matrix(y_true, y_pred))

print("\nClassification Report")
print(classification_report(y_true, y_pred))
# Out:
# ============================================================
# UNIFORM 8-BIT QUANTIZATION
# ============================================================
# Accuracy = 94.3492%
#
# Confusion Matrix
# [[520   0   1   0   0   4]
#  [  0 498   6   0   6  15]
#  [  0   1 518   1   1   4]
#  [  2   0  11 481  30   1]
#  [  0   5   1  12 483  24]
#  [  1   5   2   2  43 472]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       525
#            1       0.98      0.95      0.96       525
#            2       0.96      0.99      0.97       525
#            3       0.97      0.92      0.94       525
#            4       0.86      0.92      0.89       525
#            5       0.91      0.90      0.90       525
#
#     accuracy                           0.94      3150
#    macro avg       0.94      0.94      0.94      3150
# weighted avg       0.94      0.94      0.94      3150

# %%
############################################################
# UNIFORM 6-BIT QUANTIZATION
############################################################

import copy
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

base_model = PCA_CNN().to(device)

base_model.load_state_dict(
    torch.load("Models/best_model_32_32_48.pth")
)

base_model.eval()

uniform6_model = copy.deepcopy(base_model)

with torch.no_grad():

    for name, param in uniform6_model.named_parameters():

        if "weight" in name:

            param.data = quantize_weights(
                param.data,
                bits=6
            )

uniform6_model.eval()

y_true = []
y_pred = []

with torch.no_grad():

    for x, y in test_loader:

        x = x.to(device)

        outputs = uniform6_model(x)

        preds = outputs.argmax(1)

        y_true.extend(y.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

acc = 100*np.mean(
    np.array(y_true)==
    np.array(y_pred)
)

print("="*60)
print("UNIFORM 6-BIT QUANTIZATION")
print("="*60)
print(f"Accuracy = {acc:.4f}%")

print("\nConfusion Matrix")
print(confusion_matrix(y_true,y_pred))

print("\nClassification Report")
print(classification_report(y_true,y_pred))
# Out:
# ============================================================
# UNIFORM 6-BIT QUANTIZATION
# ============================================================
# Accuracy = 94.3492%
#
# Confusion Matrix
# [[520   0   1   0   0   4]
#  [  0 495   6   0   7  17]
#  [  0   1 518   1   1   4]
#  [  2   0  10 486  26   1]
#  [  0   3   1  14 477  30]
#  [  1   4   2   5  37 476]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       525
#            1       0.98      0.94      0.96       525
#            2       0.96      0.99      0.97       525
#            3       0.96      0.93      0.94       525
#            4       0.87      0.91      0.89       525
#            5       0.89      0.91      0.90       525
#
#     accuracy                           0.94      3150
#    macro avg       0.94      0.94      0.94      3150
# weighted avg       0.94      0.94      0.94      3150

# %%
############################################################
# LAYER-WISE QUANTIZATION SENSITIVITY
############################################################

import copy



def evaluate_model(model):

    model.eval()

    correct = 0
    total = 0

    with torch.no_grad():

        for x, y in test_loader:

            x = x.to(device)
            y = y.to(device)

            outputs = model(x)

            preds = outputs.argmax(1)

            correct += (preds == y).sum().item()
            total += y.size(0)

    return 100.0 * correct / total


############################################################
# LOAD BEST MODEL
############################################################

base_model = PCA_CNN().to(device)

base_model.load_state_dict(
    torch.load("Models/best_model_32_32_48.pth")
)

baseline_acc = evaluate_model(base_model)

print(f"\nBaseline Accuracy = {baseline_acc:.4f}%")
# Out:
# Baseline Accuracy = 94.3810%

# %%
############################################################
# TEST EACH LAYER
############################################################

layers_to_test = [
    "conv1.weight",
    "conv2.weight",
    "fc1.weight",
    "fc2.weight"
]

bitwidths = [8, 6, 4, 2]

results = {}

for layer_name in layers_to_test:

    results[layer_name] = {}

    print("\n" + "="*60)
    print("Testing:", layer_name)

    for bits in bitwidths:

        model = copy.deepcopy(base_model)

        with torch.no_grad():

            for name, param in model.named_parameters():

                if name == layer_name:

                    param.data = quantize_weights(
                        param.data,
                        bits
                    )

        acc = evaluate_model(model)

        results[layer_name][bits] = acc

        print(
            f"{bits:2d}-bit --> {acc:.4f}%"
        )
# Out:
# ============================================================
# Testing: conv1.weight
#  8-bit --> 94.3492%
#  6-bit --> 94.2222%
#  4-bit --> 94.2540%
#  2-bit --> 70.7619%
#
# ============================================================
# Testing: conv2.weight
#  8-bit --> 94.4127%
#  6-bit --> 94.5397%
#  4-bit --> 93.7460%
#  2-bit --> 53.9683%
#
# ============================================================
# Testing: fc1.weight
#  8-bit --> 94.2857%
#  6-bit --> 94.4762%
#  4-bit --> 93.0476%
#  2-bit --> 44.5714%
#
# ============================================================
# Testing: fc2.weight
#  8-bit --> 94.3810%
#  6-bit --> 94.0635%
#  4-bit --> 92.7302%
#  2-bit --> 55.7460%

# %%
############################################################
# PRINT TABLE
############################################################

print("\n")
print("="*70)
print("HAQ SENSITIVITY TABLE")
print("="*70)

for layer, vals in results.items():

    print(
        f"{layer:15s}",
        end=""
    )

    for bits in [8,6,4,2]:

        print(
            f"{vals[bits]:8.2f}",
            end=""
        )

    print()

print("\nColumns = [8bit 6bit 4bit 2bit]")
# Out:
# ======================================================================
# HAQ SENSITIVITY TABLE
# ======================================================================
# conv1.weight      94.35   94.22   94.25   70.76
# conv2.weight      94.41   94.54   93.75   53.97
# fc1.weight        94.29   94.48   93.05   44.57
# fc2.weight        94.38   94.06   92.73   55.75
#
# Columns = [8bit 6bit 4bit 2bit]

# %%
############################################################
# EXHAUSTIVE MIXED-PRECISION SEARCH
############################################################

import copy
import itertools
import pandas as pd

layers = [
    "conv1.weight",
    "conv2.weight",
    "fc1.weight",
    "fc2.weight"
]

bit_choices = [8, 6, 4]

results = []

total = len(bit_choices) ** len(layers)

count = 1

for bits in itertools.product(bit_choices, repeat=4):

    print(f"Testing {count}/{total} : {bits}")

    model = copy.deepcopy(base_model)

    with torch.no_grad():

        for name, param in model.named_parameters():

            if name in layers:

                idx = layers.index(name)

                param.data = quantize_weights(
                    param.data,
                    bits[idx]
                )

    ########################################################
    # EVALUATE
    ########################################################

    acc = evaluate_model(model)

    ########################################################
    # DEBUG FOR (8,8,8,8)
    ########################################################

    if bits == (8, 8, 8, 8):

        print("\nUniform from exhaustive search =", acc)

        print("\nWeight sums:")

        for name, param in model.named_parameters():

            if "weight" in name:

                print(name, torch.sum(param).item())

    ########################################################
    # SAVE RESULT
    ########################################################

    results.append({
        "Conv1": bits[0],
        "Conv2": bits[1],
        "FC1": bits[2],
        "FC2": bits[3],
        "Accuracy": acc
    })

    count += 1

############################################################
# CREATE DATAFRAME
############################################################

results_df = pd.DataFrame(results)

print("\nNumber of results:", len(results))

print("\n(8,8,8,8) row:")

print(
    results_df[
        (results_df["Conv1"] == 8) &
        (results_df["Conv2"] == 8) &
        (results_df["FC1"] == 8) &
        (results_df["FC2"] == 8)
    ]
)
# Out:
# Testing 1/81 : (8, 8, 8, 8)
#
# Uniform from exhaustive search = 94.34920634920636
#
# Weight sums:
# conv1.weight 7.508850574493408
# conv2.weight -27.571434020996094
# fc1.weight -54.80785369873047
# fc2.weight -30.58705711364746
# Testing 2/81 : (8, 8, 8, 6)
# Testing 3/81 : (8, 8, 8, 4)
# Testing 4/81 : (8, 8, 6, 8)
# Testing 5/81 : (8, 8, 6, 6)
# Testing 6/81 : (8, 8, 6, 4)
# Testing 7/81 : (8, 8, 4, 8)
# Testing 8/81 : (8, 8, 4, 6)
# Testing 9/81 : (8, 8, 4, 4)
# Testing 10/81 : (8, 6, 8, 8)
# Testing 11/81 : (8, 6, 8, 6)
# Testing 12/81 : (8, 6, 8, 4)
# Testing 13/81 : (8, 6, 6, 8)
# Testing 14/81 : (8, 6, 6, 6)
# Testing 15/81 : (8, 6, 6, 4)
# Testing 16/81 : (8, 6, 4, 8)
# Testing 17/81 : (8, 6, 4, 6)
# Testing 18/81 : (8, 6, 4, 4)
# Testing 19/81 : (8, 4, 8, 8)
# Testing 20/81 : (8, 4, 8, 6)
# Testing 21/81 : (8, 4, 8, 4)
# Testing 22/81 : (8, 4, 6, 8)
# Testing 23/81 : (8, 4, 6, 6)
# Testing 24/81 : (8, 4, 6, 4)
# Testing 25/81 : (8, 4, 4, 8)
# Testing 26/81 : (8, 4, 4, 6)
# Testing 27/81 : (8, 4, 4, 4)
# Testing 28/81 : (6, 8, 8, 8)
# Testing 29/81 : (6, 8, 8, 6)
# Testing 30/81 : (6, 8, 8, 4)
# Testing 31/81 : (6, 8, 6, 8)
# Testing 32/81 : (6, 8, 6, 6)
# Testing 33/81 : (6, 8, 6, 4)
# Testing 34/81 : (6, 8, 4, 8)
# Testing 35/81 : (6, 8, 4, 6)
# Testing 36/81 : (6, 8, 4, 4)
# Testing 37/81 : (6, 6, 8, 8)
# Testing 38/81 : (6, 6, 8, 6)
# Testing 39/81 : (6, 6, 8, 4)
# Testing 40/81 : (6, 6, 6, 8)
# Testing 41/81 : (6, 6, 6, 6)
# Testing 42/81 : (6, 6, 6, 4)
# Testing 43/81 : (6, 6, 4, 8)
# Testing 44/81 : (6, 6, 4, 6)
# Testing 45/81 : (6, 6, 4, 4)
# Testing 46/81 : (6, 4, 8, 8)
# Testing 47/81 : (6, 4, 8, 6)
# Testing 48/81 : (6, 4, 8, 4)
# Testing 49/81 : (6, 4, 6, 8)
# Testing 50/81 : (6, 4, 6, 6)
# Testing 51/81 : (6, 4, 6, 4)
# Testing 52/81 : (6, 4, 4, 8)
# Testing 53/81 : (6, 4, 4, 6)
# Testing 54/81 : (6, 4, 4, 4)
# Testing 55/81 : (4, 8, 8, 8)
# Testing 56/81 : (4, 8, 8, 6)
# Testing 57/81 : (4, 8, 8, 4)
# Testing 58/81 : (4, 8, 6, 8)
# Testing 59/81 : (4, 8, 6, 6)
# Testing 60/81 : (4, 8, 6, 4)
# Testing 61/81 : (4, 8, 4, 8)
# Testing 62/81 : (4, 8, 4, 6)
# Testing 63/81 : (4, 8, 4, 4)
# Testing 64/81 : (4, 6, 8, 8)
# Testing 65/81 : (4, 6, 8, 6)
# Testing 66/81 : (4, 6, 8, 4)
# Testing 67/81 : (4, 6, 6, 8)
# Testing 68/81 : (4, 6, 6, 6)
# Testing 69/81 : (4, 6, 6, 4)
# Testing 70/81 : (4, 6, 4, 8)
# Testing 71/81 : (4, 6, 4, 6)
# Testing 72/81 : (4, 6, 4, 4)
# Testing 73/81 : (4, 4, 8, 8)
# Testing 74/81 : (4, 4, 8, 6)
# Testing 75/81 : (4, 4, 8, 4)
# Testing 76/81 : (4, 4, 6, 8)
# Testing 77/81 : (4, 4, 6, 6)
# Testing 78/81 : (4, 4, 6, 4)
# Testing 79/81 : (4, 4, 4, 8)
# Testing 80/81 : (4, 4, 4, 6)
# Testing 81/81 : (4, 4, 4, 4)
#
# Number of results: 81
#
# (8,8,8,8) row:
#    Conv1  Conv2  FC1  FC2   Accuracy
# 0      8      8    8    8  94.349206

# %%
for name, param in base_model.named_parameters():
    print(name)
# Out:
# conv1.weight
# conv1.bias
# conv2.weight
# conv2.bias
# fc1.weight
# fc1.bias
# fc2.weight
# fc2.bias

# %%
############################################################
# CREATE TABLE
############################################################

results_df = pd.DataFrame(
    results,
    columns=[
        "Conv1",
        "Conv2",
        "FC1",
        "FC2",
        "Accuracy"
    ]
)

results_df = results_df.sort_values(
    by="Accuracy",
    ascending=False
)

results_df = results_df.reset_index(drop=True)

print(results_df)
# Out:
#     Conv1  Conv2  FC1  FC2   Accuracy
# 0       4      6    8    8  94.571429
# 1       8      8    6    8  94.539683
# 2       8      6    8    8  94.507937
# 3       6      8    6    8  94.476190
# 4       8      6    6    8  94.476190
# ..    ...    ...  ...  ...        ...
# 76      8      4    6    4  90.793651
# 77      4      4    4    4  90.793651
# 78      8      4    4    4  90.730159
# 79      6      4    4    4  90.571429
# 80      4      4    6    4  90.571429
#
# [81 rows x 5 columns]

# %%
results_df.to_csv(
    "Mixed_Quantization_Results.csv",
    index=False
)

print("Saved Successfully")
# Out:
# Saved Successfully

# %%
############################################################
# HARDWARE COST ANALYSIS
############################################################

import numpy as np

PARAMS = {
    "Conv1":416,
    "Conv2":2080,
    "FC1":2112,
    "FC2":390
}

# FP32 reference
FP32_BITS = (
    (PARAMS["Conv1"] +
     PARAMS["Conv2"] +
     PARAMS["FC1"] +
     PARAMS["FC2"]) * 32
)

# Calculate hardware cost
results_df["Memory(bits)"] = (
    results_df["Conv1"] * PARAMS["Conv1"] +
    results_df["Conv2"] * PARAMS["Conv2"] +
    results_df["FC1"]   * PARAMS["FC1"] +
    results_df["FC2"]   * PARAMS["FC2"]
)

results_df["Memory(KB)"] = (
    results_df["Memory(bits)"] / 8 / 1024
)

results_df["Compression"] = (
    FP32_BITS / results_df["Memory(bits)"]
)

# Xilinx BRAM18 = 18 Kbits = 18432 bits
results_df["BRAM18"] = np.ceil(
    results_df["Memory(bits)"] / 18432
).astype(int)

############################################################
# KEEP ONLY GOOD MODELS
############################################################

good_models = results_df[
    results_df["Accuracy"] >= 93.0
].copy()

good_models = good_models.sort_values(
    by=["Accuracy", "Memory(bits)"],
    ascending=[False, True]
)

good_models = good_models.reset_index(drop=True)

print(good_models)
# Out:
#     Conv1  Conv2  FC1  FC2   Accuracy  Memory(bits)  Memory(KB)  Compression  \
# 0       4      6    8    8  94.571429         34160    4.169922     4.681967
# 1       8      8    6    8  94.539683         35760    4.365234     4.472483
# 2       8      6    8    8  94.507937         35824    4.373047     4.464493
# 3       6      6    6    8  94.476190         30768    3.755859     5.198128
# 4       8      6    6    8  94.476190         31600    3.857422     5.061266
# 5       6      8    6    8  94.476190         34928    4.263672     4.579020
# 6       6      8    8    8  94.412698         39152    4.779297     4.085002
# 7       6      6    8    8  94.380952         34992    4.271484     4.570645
# 8       4      8    8    8  94.380952         38320    4.677734     4.173695
# 9       6      6    6    6  94.349206         29988    3.660645     5.333333
# 10      8      8    8    8  94.349206         39984    4.880859     4.000000
# 11      4      6    6    8  94.317460         29936    3.654297     5.342598
# 12      6      6    8    6  94.317460         34212    4.176270     4.674851
# 13      8      6    8    6  94.317460         35044    4.277832     4.563863
# 14      8      6    6    6  94.285714         30820    3.762207     5.189358
# 15      4      8    6    8  94.222222         34096    4.162109     4.690756
# 16      8      8    8    6  94.190476         39204    4.785645     4.079584
# 17      6      8    8    6  94.158730         38372    4.684082     4.168039
# 18      8      8    6    6  94.063492         34980    4.270020     4.572213
# 19      4      6    8    6  94.000000         33380    4.074707     4.791372
# 20      6      8    6    6  94.000000         34148    4.168457     4.683613
# 21      4      8    8    6  93.936508         37540    4.582520     4.260416
# 22      6      4    8    8  93.873016         30832    3.763672     5.187338
# 23      8      4    8    8  93.809524         31664    3.865234     5.051036
# 24      4      6    6    6  93.777778         29156    3.559082     5.485526
# 25      6      4    6    8  93.714286         26608    3.248047     6.010824
# 26      8      4    4    8  93.587302         23216    2.833984     6.889042
# 27      4      8    6    6  93.587302         33316    4.066895     4.800576
# 28      6      4    4    8  93.555556         22384    2.732422     7.145104
# 29      8      4    4    6  93.460317         22436    2.738770     7.128543
# 30      4      4    8    8  93.460317         30000    3.662109     5.331200
# 31      6      4    8    6  93.428571         30052    3.668457     5.321975
# 32      6      4    4    6  93.396825         21604    2.637207     7.403074
# 33      8      4    6    8  93.396825         27440    3.349609     5.828571
# 34      4      4    4    8  93.365079         21552    2.630859     7.420935
# 35      4      4    4    6  93.301587         20772    2.535645     7.699596
# 36      8      8    4    6  93.206349         30756    3.754395     5.200156
# 37      8      4    8    6  93.174603         30884    3.770020     5.178604
# 38      4      8    4    6  93.111111         29092    3.551270     5.497594
# 39      6      8    4    6  93.111111         29924    3.652832     5.344740
#
#     BRAM18
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
# 5        2
# 6        3
# 7        2
# 8        3
# 9        2
# 10       3
# 11       2
# 12       2
# 13       2
# 14       2
# 15       2
# 16       3
# 17       3
# 18       2
# 19       2
# 20       2
# 21       3
# 22       2
# 23       2
# 24       2
# 25       2
# 26       2
# 27       2
# 28       2
# 29       2
# 30       2
# 31       2
# 32       2
# 33       2
# 34       2
# 35       2
# 36       2
# 37       2
# 38       2
# 39       2

# %%
############################################################
# SAVE RESULTS
############################################################

good_models.to_csv(
    "Hardware_Aware_Results.csv",
    index=False
)

print("Saved Successfully!")

print("\nTop Hardware-Aware Models\n")
print(good_models)
# Out:
# Saved Successfully!
#
# Top Hardware-Aware Models
#
#     Conv1  Conv2  FC1  FC2   Accuracy  Memory(bits)  Memory(KB)  Compression  \
# 0       4      6    8    8  94.571429         34160    4.169922     4.681967
# 1       8      8    6    8  94.539683         35760    4.365234     4.472483
# 2       8      6    8    8  94.507937         35824    4.373047     4.464493
# 3       6      6    6    8  94.476190         30768    3.755859     5.198128
# 4       8      6    6    8  94.476190         31600    3.857422     5.061266
# 5       6      8    6    8  94.476190         34928    4.263672     4.579020
# 6       6      8    8    8  94.412698         39152    4.779297     4.085002
# 7       6      6    8    8  94.380952         34992    4.271484     4.570645
# 8       4      8    8    8  94.380952         38320    4.677734     4.173695
# 9       6      6    6    6  94.349206         29988    3.660645     5.333333
# 10      8      8    8    8  94.349206         39984    4.880859     4.000000
# 11      4      6    6    8  94.317460         29936    3.654297     5.342598
# 12      6      6    8    6  94.317460         34212    4.176270     4.674851
# 13      8      6    8    6  94.317460         35044    4.277832     4.563863
# 14      8      6    6    6  94.285714         30820    3.762207     5.189358
# 15      4      8    6    8  94.222222         34096    4.162109     4.690756
# 16      8      8    8    6  94.190476         39204    4.785645     4.079584
# 17      6      8    8    6  94.158730         38372    4.684082     4.168039
# 18      8      8    6    6  94.063492         34980    4.270020     4.572213
# 19      4      6    8    6  94.000000         33380    4.074707     4.791372
# 20      6      8    6    6  94.000000         34148    4.168457     4.683613
# 21      4      8    8    6  93.936508         37540    4.582520     4.260416
# 22      6      4    8    8  93.873016         30832    3.763672     5.187338
# 23      8      4    8    8  93.809524         31664    3.865234     5.051036
# 24      4      6    6    6  93.777778         29156    3.559082     5.485526
# 25      6      4    6    8  93.714286         26608    3.248047     6.010824
# 26      8      4    4    8  93.587302         23216    2.833984     6.889042
# 27      4      8    6    6  93.587302         33316    4.066895     4.800576
# 28      6      4    4    8  93.555556         22384    2.732422     7.145104
# 29      8      4    4    6  93.460317         22436    2.738770     7.128543
# 30      4      4    8    8  93.460317         30000    3.662109     5.331200
# 31      6      4    8    6  93.428571         30052    3.668457     5.321975
# 32      6      4    4    6  93.396825         21604    2.637207     7.403074
# 33      8      4    6    8  93.396825         27440    3.349609     5.828571
# 34      4      4    4    8  93.365079         21552    2.630859     7.420935
# 35      4      4    4    6  93.301587         20772    2.535645     7.699596
# 36      8      8    4    6  93.206349         30756    3.754395     5.200156
# 37      8      4    8    6  93.174603         30884    3.770020     5.178604
# 38      4      8    4    6  93.111111         29092    3.551270     5.497594
# 39      6      8    4    6  93.111111         29924    3.652832     5.344740
#
#     BRAM18
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
# 5        2
# 6        3
# 7        2
# 8        3
# 9        2
# 10       3
# 11       2
# 12       2
# 13       2
# 14       2
# 15       2
# 16       3
# 17       3
# 18       2
# 19       2
# 20       2
# 21       3
# 22       2
# 23       2
# 24       2
# 25       2
# 26       2
# 27       2
# 28       2
# 29       2
# 30       2
# 31       2
# 32       2
# 33       2
# 34       2
# 35       2
# 36       2
# 37       2
# 38       2
# 39       2

# %%
print("Conv1 :", model.conv1.weight.numel())
print("Conv2 :", model.conv2.weight.numel())
print("FC1   :", model.fc1.weight.numel())
print("FC2   :", model.fc2.weight.numel())
# Out:
# Conv1 : 384
# Conv2 : 2048
# FC1   : 1536
# FC2   : 288
